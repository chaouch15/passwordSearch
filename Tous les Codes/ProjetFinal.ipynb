# %% [markdown]
# ##Install and Imports

# %%
# !pip install flair
# Out:
# Collecting flair
#   Downloading flair-0.13.1-py3-none-any.whl (388 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 388.3/388.3 kB 2.7 MB/s eta 0:00:00
# Collecting boto3>=1.20.27 (from flair)
#   Downloading boto3-1.34.35-py3-none-any.whl (139 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.3/139.3 kB 13.9 MB/s eta 0:00:00
# Collecting bpemb>=0.3.2 (from flair)
#   Downloading bpemb-0.3.4-py3-none-any.whl (19 kB)
# Collecting conllu>=4.0 (from flair)
#   Downloading conllu-4.5.3-py2.py3-none-any.whl (16 kB)
# Collecting deprecated>=1.2.13 (from flair)
#   Downloading Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Collecting ftfy>=6.1.0 (from flair)
#   Downloading ftfy-6.1.3-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.4/53.4 kB 6.5 MB/s eta 0:00:00
# Requirement already satisfied: gdown>=4.4.0 in /usr/local/lib/python3.10/dist-packages (from flair) (4.7.3)
# Requirement already satisfied: gensim>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from flair) (4.3.2)
# Requirement already satisfied: huggingface-hub>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from flair) (0.20.3)
# Collecting janome>=0.4.2 (from flair)
#   Downloading Janome-0.5.0-py2.py3-none-any.whl (19.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.7/19.7 MB 34.5 MB/s eta 0:00:00
# Collecting langdetect>=1.0.9 (from flair)
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 47.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: lxml>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from flair) (4.9.4)
# Requirement already satisfied: matplotlib>=2.2.3 in /usr/local/lib/python3.10/dist-packages (from flair) (3.7.1)
# Requirement already satisfied: more-itertools>=8.13.0 in /usr/local/lib/python3.10/dist-packages (from flair) (10.1.0)
# Collecting mpld3>=0.3 (from flair)
#   Downloading mpld3-0.5.10-py3-none-any.whl (202 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 202.6/202.6 kB 17.8 MB/s eta 0:00:00
# Collecting pptree>=3.1 (from flair)
#   Downloading pptree-3.1.tar.gz (3.0 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from flair) (2.8.2)
# Collecting pytorch-revgrad>=0.2.0 (from flair)
#   Downloading pytorch_revgrad-0.2.0-py3-none-any.whl (4.6 kB)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.10/dist-packages (from flair) (2023.12.25)
# Requirement already satisfied: scikit-learn>=1.0.2 in /usr/local/lib/python3.10/dist-packages (from flair) (1.2.2)
# Collecting segtok>=1.5.11 (from flair)
#   Downloading segtok-1.5.11-py3-none-any.whl (24 kB)
# Collecting sqlitedict>=2.0.0 (from flair)
#   Downloading sqlitedict-2.1.0.tar.gz (21 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tabulate>=0.8.10 in /usr/local/lib/python3.10/dist-packages (from flair) (0.9.0)
# Requirement already satisfied: torch!=1.8,>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from flair) (2.1.0+cu121)
# Requirement already satisfied: tqdm>=4.63.0 in /usr/local/lib/python3.10/dist-packages (from flair) (4.66.1)
# Collecting transformer-smaller-training-vocab>=0.2.3 (from flair)
#   Downloading transformer_smaller_training_vocab-0.3.3-py3-none-any.whl (14 kB)
# Requirement already satisfied: transformers[sentencepiece]<5.0.0,>=4.18.0 in /usr/local/lib/python3.10/dist-packages (from flair) (4.35.2)
# Collecting urllib3<2.0.0,>=1.0.0 (from flair)
#   Downloading urllib3-1.26.18-py2.py3-none-any.whl (143 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.8/143.8 kB 17.8 MB/s eta 0:00:00
# Collecting wikipedia-api>=0.5.7 (from flair)
#   Downloading Wikipedia_API-0.6.0-py3-none-any.whl (14 kB)
# Collecting semver<4.0.0,>=3.0.0 (from flair)
#   Downloading semver-3.0.2-py3-none-any.whl (17 kB)
# Collecting botocore<1.35.0,>=1.34.35 (from boto3>=1.20.27->flair)
#   Downloading botocore-1.34.35-py3-none-any.whl (11.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.9/11.9 MB 32.6 MB/s eta 0:00:00
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3>=1.20.27->flair)
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Collecting s3transfer<0.11.0,>=0.10.0 (from boto3>=1.20.27->flair)
#   Downloading s3transfer-0.10.0-py3-none-any.whl (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.1/82.1 kB 9.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from bpemb>=0.3.2->flair) (1.23.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from bpemb>=0.3.2->flair) (2.31.0)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from bpemb>=0.3.2->flair) (0.1.99)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.10/dist-packages (from deprecated>=1.2.13->flair) (1.14.1)
# Requirement already satisfied: wcwidth<0.3.0,>=0.2.12 in /usr/local/lib/python3.10/dist-packages (from ftfy>=6.1.0->flair) (0.2.13)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from gdown>=4.4.0->flair) (3.13.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from gdown>=4.4.0->flair) (1.16.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from gdown>=4.4.0->flair) (4.12.3)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from gensim>=4.2.0->flair) (1.11.4)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from gensim>=4.2.0->flair) (6.4.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.10.0->flair) (2023.6.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.10.0->flair) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.10.0->flair) (4.5.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.10.0->flair) (23.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.2.3->flair) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.2.3->flair) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.2.3->flair) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.2.3->flair) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.2.3->flair) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.2.3->flair) (3.1.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from mpld3>=0.3->flair) (3.1.3)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.2->flair) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.2->flair) (3.2.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch!=1.8,>=1.5.0->flair) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch!=1.8,>=1.5.0->flair) (3.2.1)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch!=1.8,>=1.5.0->flair) (2.1.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]<5.0.0,>=4.18.0->flair) (0.15.1)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]<5.0.0,>=4.18.0->flair) (0.4.2)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]<5.0.0,>=4.18.0->flair) (3.20.3)
# Collecting accelerate>=0.20.3 (from transformers[sentencepiece]<5.0.0,>=4.18.0->flair)
#   Downloading accelerate-0.26.1-py3-none-any.whl (270 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 270.9/270.9 kB 14.6 MB/s eta 0:00:00
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->gdown>=4.4.0->flair) (2.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->mpld3>=0.3->flair) (2.1.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->bpemb>=0.3.2->flair) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->bpemb>=0.3.2->flair) (3.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->bpemb>=0.3.2->flair) (2023.11.17)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests->bpemb>=0.3.2->flair) (1.7.1)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch!=1.8,>=1.5.0->flair) (1.3.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.20.3->transformers[sentencepiece]<5.0.0,>=4.18.0->flair) (5.9.5)
# Building wheels for collected packages: langdetect, pptree, sqlitedict
#   Building wheel for langdetect (setup.py) ... done
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993225 sha256=d8eed9c7a3ba96fdde3cb620af56ed5625afd8d4a6f1448f126a58c31844c82a
#   Stored in directory: /root/.cache/pip/wheels/95/03/7d/59ea870c70ce4e5a370638b5462a7711ab78fba2f655d05106
#   Building wheel for pptree (setup.py) ... done
#   Created wheel for pptree: filename=pptree-3.1-py3-none-any.whl size=4608 sha256=6d523a51db9a3529ab6d9c9c7662dbb2eeeb974a90b93b5f3e7fdc48bfad928d
#   Stored in directory: /root/.cache/pip/wheels/9f/b6/0e/6f26eb9e6eb53ff2107a7888d72b5a6a597593956113037828
#   Building wheel for sqlitedict (setup.py) ... done
#   Created wheel for sqlitedict: filename=sqlitedict-2.1.0-py3-none-any.whl size=16863 sha256=33019716ca04731c08eb95e396987cd8bc31c23aa2c75196119de933f54de031
#   Stored in directory: /root/.cache/pip/wheels/79/d6/e7/304e0e6cb2221022c26d8161f7c23cd4f259a9e41e8bbcfabd
# Successfully built langdetect pptree sqlitedict
# Installing collected packages: sqlitedict, pptree, janome, urllib3, semver, segtok, langdetect, jmespath, ftfy, deprecated, conllu, botocore, wikipedia-api, s3transfer, pytorch-revgrad, mpld3, bpemb, boto3, accelerate, transformer-smaller-training-vocab, flair
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.0.7
#     Uninstalling urllib3-2.0.7:
#       Successfully uninstalled urllib3-2.0.7
# Successfully installed accelerate-0.26.1 boto3-1.34.35 botocore-1.34.35 bpemb-0.3.4 conllu-4.5.3 deprecated-1.2.14 flair-0.13.1 ftfy-6.1.3 janome-0.5.0 jmespath-1.0.1 langdetect-1.0.9 mpld3-0.5.10 pptree-3.1 pytorch-revgrad-0.2.0 s3transfer-0.10.0 segtok-1.5.11 semver-3.0.2 sqlitedict-2.1.0 transformer-smaller-training-vocab-0.3.3 urllib3-1.26.18 wikipedia-api-0.6.0

# %%
# !pip install vaderSentiment-fr
# Out:
# Collecting vaderSentiment-fr
#   Downloading vaderSentiment_fr-1.3.4.tar.gz (187 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 187.1/187.1 kB 1.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting unidecode (from vaderSentiment-fr)
#   Downloading Unidecode-1.3.8-py3-none-any.whl (235 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.5/235.5 kB 1.3 MB/s eta 0:00:00
# Collecting fuzzywuzzy (from vaderSentiment-fr)
#   Downloading fuzzywuzzy-0.18.0-py2.py3-none-any.whl (18 kB)
# Building wheels for collected packages: vaderSentiment-fr
#   Building wheel for vaderSentiment-fr (setup.py) ... done
#   Created wheel for vaderSentiment-fr: filename=vaderSentiment_fr-1.3.4-py3-none-any.whl size=185960 sha256=1a2c6da007e021237a278fbc11bb9c2bb06c5e3a6f9cc768d8ca1dcb160a0dfa
#   Stored in directory: /root/.cache/pip/wheels/a3/a0/97/307bbd5f16d2e240c69421a79a42a18797067af832ee955b09
# Successfully built vaderSentiment-fr
# Installing collected packages: fuzzywuzzy, unidecode, vaderSentiment-fr
# Successfully installed fuzzywuzzy-0.18.0 unidecode-1.3.8 vaderSentiment-fr-1.3.4

# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2023.11.17)

# %%
# !python -m spacy download fr_core_news_sm
# Out:
# Collecting fr-core-news-sm==3.7.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/fr_core_news_sm-3.7.0/fr_core_news_sm-3.7.0-py3-none-any.whl (16.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.3/16.3 MB 23.7 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.0 in /usr/local/lib/python3.10/dist-packages (from fr-core-news-sm==3.7.0) (3.7.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (8.2.2)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (4.66.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (1.10.14)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (3.1.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (1.23.5)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (2023.11.17)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (2.1.4)
# Installing collected packages: fr-core-news-sm
# Successfully installed fr-core-news-sm-3.7.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('fr_core_news_sm')

# %%
import requests
from pprint import pprint
import os
import pandas as pd
import numpy as np
from flair.data import Sentence
from flair.models import SequenceTagger
import json
import re
import random
from tqdm import tqdm

import nltk
nltk.download('punkt')
nltk.download('stopwords')

from nltk.corpus import stopwords
from vaderSentiment_fr.vaderSentiment import SentimentIntensityAnalyzer
from nltk import tokenize
from nltk.corpus import stopwords
from nltk.stem.snowball import SnowballStemmer

stopWords = set(stopwords.words('french'))
stemmer = SnowballStemmer(language='french')

import spacy
nlp = spacy.load("fr_core_news_sm")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# /usr/local/lib/python3.10/dist-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
# mount my Google Drive on the VM

from google.colab import drive
drive.mount('/gdrive')

DIR_PROJECT = '/gdrive/MyDrive/Projet5ADD/Tous les Codes'
DIR_LEXICON = os.path.join(DIR_PROJECT,'Code Sentiment Analysis/French-NRC-EmoLex.txt')
# Out:
# Mounted at /gdrive

# %% [markdown]
# #Extracting important words and reducing text

# %%
stopWords.add("n’")
stopWords.add("l’")
stopWords.add("c’")

# %%
#takes a sentence as a uniq string, returns a list of words without the stopwords
def cleaning_sentence(sentence):
  clean =[]
  for token in nlp(sentence):
    if token.text not in stopWords:
        clean.append(token.text)
  return clean

# %%
#Supposé réduire les mots à leur racine marche approximativement
def racine(sentence):
    return [stemmer.stem(X.text) for X in nlp(sentence)]

# %%
#classifie par type grammatical
def gramm(sentence):
    return [(X, X.pos_) for X in nlp(sentence)]

# %%
#prends une phrase, vire les stopwords, renvoie la racine et le type des mots restant (note: si le mot est un nom propre, racine et type seront erronés)
def extract_racines(sentence):
  nl = nlp(sentence)
  clean =[]
  for token in nlp(sentence):
    if token.text not in stopWords:
        clean.append(token)
  #return [(stemmer.stem(X.text),X.pos_) for X in clean]
  return [(X.text,X.pos_) for X in clean]

# %%
#trie le resultat de extract_racines pour ne garder que les noms et adjectifs
def filter_words(list_words):
  ret = []
  for words in list_words:
    if words[1] in ['ADJ','PROPN','NOUN']:
       ret.append(words[0])
  return ret

# %%
#TEST:
test = "Mélodie raconte une histoire, qui a eu lieu en 2013, sur son chien, Rex. Elle essaye depuis des années de publier son livre Rainbow, en Europe, plus partiuclièrement en France. C'est vrai qu'elle adore son chien. Elle aime la France du fond du coeur. Mais elle cherche aussi à devenir une star comme Macron."
filter_words(extract_racines(test))
# Out:
# ['Mélodie',
#  'raconte',
#  'histoire',
#  'lieu',
#  'chien',
#  'Rex',
#  'années',
#  'publier',
#  'livre',
#  'Rainbow',
#  'Europe',
#  'France',
#  'vrai',
#  'chien',
#  'France',
#  'fond',
#  'coeur',
#  'star',
#  'Macron']

# %% [markdown]
# #Web-Scrapping

# %%
payload = {
    'source': 'google_search',
    'query': 'Wissal El-Kourdi',
    'parse': True,
    'no_images': True,
    'start_page': 1,
    'pages': 5,
    'limit': 10,
}


# Get response.
response = requests.request(
    'POST',
    'https://realtime.oxylabs.io/v1/queries',
    auth=('wissal', 'Maha10301030'),
    json=payload,
)


if response.status_code != 200:
    print("Error - ", response.json())
    exit(-1)


pprint(response.json())
# Out:
# Error -  {'message': 'Too many requests. (Product Fixed (successful only)).'}
# {'message': 'Too many requests. (Product Fixed (successful only)).'}

# %%
text_json = json.loads(response.text)

# %%
text_json.keys()
# Out:
# dict_keys(['message'])

# %%
json_results = text_json['results']
type(json_results)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-54e2f25415b2> in <cell line: 1>()
# ----> 1 json_results = text_json['results']
#       2 type(json_results)
#
# KeyError: 'results'

# %%
description = []
for url in json_results:
  for content in (url['content']['results']['organic']):
      description.append(content['desc'])
description

# %%
text_to_NER = ' '.join(description)

# %%
text_to_NER.replace(u'\xa0', u' ')

# %% [markdown]
# #Pre-trained NER model

# %% [markdown]
# From https://huggingface.co/flair/ner-english-ontonotes-large

# %%
tagger = SequenceTagger.load("flair/ner-english-ontonotes-large")

def Retrieve_NER(sentence_string):
    """
    Retrieve Named Entities from a given sentence using Flair NER.

    Parameters:
    - sentence_string (str): The input sentence.

    Returns:
    - dict: A dictionary containing lists of entities for each NER category.
    """
    sentence = Sentence(sentence_string)

    # Predict entities
    tagger.predict(sentence)

    # Initialize a dictionary for storing unique entities for each category
    predicted_map = {
        'CARDINAL': set(),
        'DATE': set(),
        'EVENT': set(),
        'FAC': set(),
        'GPE': set(),
        'LANGUAGE': set(),
        'LAW': set(),
        'LOC': set(),
        'MONEY': set(),
        'NORP': set(),
        'ORDINAL': set(),
        'ORG': set(),
        'PERCENT': set(),
        'PERSON': set(),
        'PRODUCT': set(),
        'QUANTITY': set(),
        'TIME': set(),
        'WORK_OF_ART': set()
    }

    # Populate the dictionary with unique entities
    for entity in sentence.get_spans('ner'):
        text = entity.text.lower()
        predicted_map[entity.tag].add(text)

    return predicted_map
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# pytorch_model.bin:   0%|          | 0.00/2.24G [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/616 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.10M [00:00<?, ?B/s]
# 2024-02-06 13:20:17,301 SequenceTagger predicts: Dictionary with 76 tags: <unk>, O, B-CARDINAL, E-CARDINAL, S-PERSON, S-CARDINAL, S-PRODUCT, B-PRODUCT, I-PRODUCT, E-PRODUCT, B-WORK_OF_ART, I-WORK_OF_ART, E-WORK_OF_ART, B-PERSON, E-PERSON, S-GPE, B-DATE, I-DATE, E-DATE, S-ORDINAL, S-LANGUAGE, I-PERSON, S-EVENT, S-DATE, B-QUANTITY, E-QUANTITY, S-TIME, B-TIME, I-TIME, E-TIME, B-GPE, E-GPE, S-ORG, I-GPE, S-NORP, B-FAC, I-FAC, E-FAC, B-NORP, E-NORP, S-PERCENT, B-ORG, E-ORG, B-LANGUAGE, E-LANGUAGE, I-CARDINAL, I-ORG, S-WORK_OF_ART, I-QUANTITY, B-MONEY

# %%
text_to_NER= "Mélodie raconte une histoire, qui a eu lieu en 2013, sur son chien, Rex. Elle essaye depuis des années de publier son livre Rainbow, en Europe, plus partiuclièrement en France. C'est vrai qu'elle adore son chien. Elle aime la France du fond du coeur. Mais elle cherche aussi à devenir une star comme Macron."
NER_to_algebra = Retrieve_NER(text_to_NER)

# %%
NER_to_algebra
# Out:
# {'CARDINAL': set(),
#  'DATE': {'2013', 'des années'},
#  'EVENT': set(),
#  'FAC': set(),
#  'GPE': {'france'},
#  'LANGUAGE': set(),
#  'LAW': set(),
#  'LOC': {'europe'},
#  'MONEY': set(),
#  'NORP': set(),
#  'ORDINAL': set(),
#  'ORG': set(),
#  'PERCENT': set(),
#  'PERSON': {'macron', 'mélodie', 'rex'},
#  'PRODUCT': set(),
#  'QUANTITY': set(),
#  'TIME': set(),
#  'WORK_OF_ART': {'rainbow'}}

# %% [markdown]
# #Sentiment Classification

# %%
# Load NRC Emotion Lexicon

# METHODE 1
#print('DIR_LEXICON =', DIR_LEXICON)
#lexicon = pd.read_csv(DIR_LEXICON, sep='\t')

# METHODE 2
url = 'https://drive.google.com/file/d/1NGU4J7mhlqdJplLuVpjQJdq5OD5QTYGd/view?usp=sharing'
file_id = url.split('/')[-2]
read_url='https://drive.google.com/uc?id=' + file_id
# read the data
lexicon = pd.read_csv(read_url)

# %%
# Create an instance of the VADER sentiment analyzer
analyzer = SentimentIntensityAnalyzer()

# Define a function to perform sentiment analysis using VADER
def get_sentiment(tweet):
    sentiment = analyzer.polarity_scores(tweet)
    compound_score = sentiment['compound']
    return compound_score

# Define a function to categorize sentiment based on VADER score
def categorize_sentiment(score):
    if score < 0:
        return 'negative'
    elif score > 0:
        return 'positive'
    else:
        return 'neutral'

# Define a function to perform emotion detection using the lexicon
def detect_emotion(tweet):

    emotions = {'anger': 0, 'anticipation': 0, 'disgust': 0, 'fear': 0, 'joy': 0, 'sadness': 0, 'surprise': 0, 'trust': 0}

    words = tweet.lower().split()
    emotion_col = set(emotions.keys())
    for word in words:
        matches = lexicon[(lexicon['French Word'] == word)]
        if not matches.empty:
          for emotion in emotion_col:
            emotions[emotion] += matches[emotion].iloc[0]

    # Check if all emotion values are still zero
    if all(value == 0 for value in emotions.values()):
        return None

    # Determine the predominant emotion
    predominant_emotion = max(emotions, key=emotions.get)

    return predominant_emotion

# %%
#Returns a list of positive sentences from a list of sentences
def from_text_to_positive_sentences(list_sentences):
  positive_sentences = []
  for sentence in list_sentences:
    if get_sentiment(sentence)>0:
      positive_sentences.append(sentence)
  return positive_sentences

# %%
# Example sentence
example_sentence = "Fais chier, il pleut. Hier j'ai acheté une baguette. Elle était bonne. Sacré journée que nous avons eu là ! J'aime beaucoup les croissants. Je souffre jour après jour, mais on fait avec. Mes rhumatismes ne vont pas mieux mais merci de t'en soucier. Va crever ! Je suis allé courir ce matin. Il fait tellement chaud, on se croirait au printemps. "
example_sentence2 = "Mélodie raconte une histoire, qui a eu lieu en 2013, sur son chien, Rex. Elle essaye depuis des années de publier son livre Rainbow, en Europe, plus partiuclièrement en France. C'est vrai qu'elle adore son chien. Elle aime la France du fond du coeur. Mais elle cherche aussi à devenir une star comme Macron."
list_sentences = tokenize.sent_tokenize(example_sentence)
list_sentences2 = tokenize.sent_tokenize(example_sentence2)

# %%
from_text_to_positive_sentences(list_sentences)
#from_text_to_positive_sentences(list_sentences2)
# Out:
# ['Elle était bonne.', "J'aime beaucoup les croissants."]

# %% [markdown]
# #Assembling the filtering parts

# %% [markdown]
# INPUT: FIRST PROFILE (insta for example)

# %%
input = "Georges est un homme de taille moyenne, de poids moyen, de visage banal, et à vrai dire, il ne présente aucun signe distinctif qui justifierais qu’on l’évoque ici, si ce n’est que d’après le commissaire, il était charmant. Georges est camionneur de profession, mais avant tout de passion, passion qui l’a même poussé à arrêter ses études de mathématiques, lorsqu’il a découvert qu’un mathématicien était rarement amené à conduire des camions. Il aime également beaucoup les chiffres et les choses symétriques, comme nous avons pu le constater précédemment. Cette passion l’a même poussé par le passé à acheter des choses dont il n’avait absolument pas besoin, juste pour satisfaire la symétrie de son appartement. Georges vit donc dans un appartement, modeste loft positionné au plein centre de Toulouse, hérité de ses parents, décédés d’un accident de chasse il y a de cela des années. Pour ce qui est de l’héritage, Georges n’aura pas eu à se battre, étant fils unique, et voilà donc pourquoi il habite là, malgré un salaire de camionneur qui ne lui permettrais pas d’acheter pareil endroit. Georges est un homme de goût, et en tant qu’homme de goût, il aime manger son pâté de campagne sur un pain de mie Harrys (celui aux céréales). C’est en revenant de ses courses que l’accident est arrivé. L’accident, en lui-même, n’avait que peu d’importance et n’allait pas impacter la vie de Georges outre mesure, si ce n’est pour le doux souvenir d’avoir mangé un excellent aligot."

# %%
def occurrences_NER(list_sentences):
    rows = []
    NER_glob = pd.DataFrame(columns=['CARDINAL','DATE','EVENT','FAC','GPE','LANGUAGE','LAW','LOC','MONEY','NORP','ORDINAL','ORG','PERCENT','PERSON','PRODUCT','QUANTITY','TIME','WORK_OF_ART'])
    for sentence in list_sentences:
        NER = Retrieve_NER(sentence)
        for key, word_list in NER.items():
            for word in word_list:
                new_row = pd.Series(index=NER_glob.columns)
                new_row[key] = word
                rows.append(new_row)
    NER_glob = pd.DataFrame(rows, columns=NER_glob.columns)
    return NER_glob

# %%
#First decompose in sentences
list_sentences = tokenize.sent_tokenize(input)

#Second NER directly

NER_neutral = occurrences_NER(list_sentences)

#Third Positive processing, only keep positive sentences
list_positive_sentences = from_text_to_positive_sentences(list_sentences)

#Fourth NLP process to get nouns, adj
list_words_NLP =[]
for sentence in list_positive_sentences:
  list_words_NLP.append(filter_words(extract_racines(sentence)))

#Five second NER on the positive sentences
NER_positive = occurrences_NER(list_positive_sentences)

#Add every result in a biiig dataframe and concacenate similar occurences, count them
NER_tot = pd.concat([NER_neutral, NER_positive], ignore_index=True)

#We have the dataframe NER_tot of words by NER category and the list_words_NLP of words
# Out:
# <ipython-input-31-0a2d129cb81c>:8: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   new_row = pd.Series(index=NER_glob.columns)
# <ipython-input-31-0a2d129cb81c>:8: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   new_row = pd.Series(index=NER_glob.columns)

# %%
#here we do a quick data squeezing to add every words from both sets in a new dataframe where there is also the number of occurences.

# Initialize df_words with word, occurrences, and NER_category columns
df_words = pd.DataFrame(columns=['word','NER_category','occurrences']) #TASNIM : added the ner_category
word_counts = pd.Series(list_words_NLP).value_counts()

# Step 1: Extract words and their occurrences from list_words_NLP
for word_list in list_words_NLP:
    word_list = [word.lower() for word in word_list]
    word_counts = pd.Series(word_list).value_counts()
    new_df = pd.DataFrame({'word': word_counts.index, 'occurrences': word_counts.values})
    new_df['NER_category'] = 'N/A'  #TASNIM :  Initialize NER category as 'N/A'
    df_words = pd.concat([df_words, new_df], ignore_index=True)

# TASNIM

# Step 2: Update NER category for words from NER results in NER_tot
for idx, row in NER_tot.iterrows():
    for col in NER_tot.columns[1:]:  # Exclude the first column 'NER TOT'
        word = row[col]
        if pd.notnull(word):
            word = word.lower()
            # Update NER category for the corresponding word in df_words
            df_words.loc[df_words['word'] == word, 'NER_category'] = col

# Step 3: Group by word and NER_category and sum the occurrences
df_words = df_words.groupby(['word', 'NER_category'], as_index=False)['occurrences'].sum()

# Step 4: Sort by occurrences in descending order
df_words = df_words.sort_values(by='occurrences', ascending=False)

# Step 5: Reset index
df_words.reset_index(drop=True, inplace=True)

df_words

# MERLIN

#word_counts = NER_tot.apply(lambda row: row.dropna().iloc[0], axis=1).value_counts()
#new_df = pd.DataFrame({'word': word_counts.index, 'occurrences': word_counts.values})
#df_words = pd.concat([df_words, new_df.groupby('word')['occurrences'].sum().reset_index()], ignore_index=True)
#sum duplicates
#df_words = df_words.groupby('word', as_index=False)['occurrences'].sum()
#df_words = df_words.sort_values(by='occurrences', ascending=False)
#df_words
# Out:
#              word NER_category  occurrences
# 0         georges       PERSON            5
# 1           homme          N/A            3
# 2         passion          N/A            3
# 3      camionneur          N/A            2
# 4            goût          N/A            2
# 5          choses          N/A            2
# 6        accident          N/A            1
# 7           poids          N/A            1
# 8             mie          N/A            1
# 9           moyen          N/A            1
# 10        moyenne          N/A            1
# 11           pain          N/A            1
# 12         pareil          N/A            1
# 13          passé          N/A            1
# 14           pâté          N/A            1
# 15     profession          N/A            1
# 16  mathématiques          N/A            1
# 17        salaire          N/A            1
# 18          signe          N/A            1
# 19       symétrie          N/A            1
# 20    symétriques          N/A            1
# 21         taille          N/A            1
# 22         unique          N/A            1
# 23            vie          N/A            1
# 24         visage          N/A            1
# 25         études          N/A            1
# 26         mesure          N/A            1
# 27   justifierais          N/A            1
# 28  mathématicien          N/A            1
# 29        lorsqu’          N/A            1
# 30    appartement          N/A            1
# 31          banal          N/A            1
# 32         battre          N/A            1
# 33         besoin          N/A            1
# 34        camions          N/A            1
# 35       campagne          N/A            1
# 36       charmant          N/A            1
# 37       chiffres          N/A            1
# 38    commissaire          N/A            1
# 39       céréales          N/A            1
# 40     distinctif          N/A            1
# 41           doux          N/A            1
# 42        endroit          N/A            1
# 43      excellent          N/A            1
# 44           fils          N/A            1
# 45         harrys       PERSON            1
# 46       héritage          N/A            1
# 47     importance          N/A            1
# 48         aligot          N/A            1
# 49         évoque          N/A            1

# %% [markdown]
# End of here we have two main list of words:
# *   df_words, words classified by number of occurrences in the combined sum of NER, and after positive combination NLP
# * NER_tot ou NER_neutral/NER_positive: NER dataframes

# %% [markdown]
# INPUT SECOND PROFILE (fb for ex)

# %%
input = 'blablabala'

# %% [markdown]
# INPUT BOTH PROFILES

# %%
input = 'blablabala'

# %% [markdown]
# #Combination and Algebra

# %% [markdown]
# > Main Functions
#     > - FILTER : NER dictionary → GPE, LOC, PERSON, CARDINAL, DATE
#     > - SORT : according to the num of occurrences
#     > - BUILD : the String Dictionary
#     > - BUILD : the Digit Dictionary
#     > - BUILD : the Special Dictionary
#     > - Compose according to minimal requirement of most websites :
#         - min 8 characters
#         - string special digits
#         - string digits special
#
# > String Categories :
# >
# > - Name (masculine, feminine, animal) : Person_NER
# > - Article : {I, my, the, it, we, you …}
# > - City : GPE_NER , Location_NER
# > - Keyboard : {qwerty, qwe, abc, asd,..}
# > - Prepositions : {to, in …}
#
# > Digit Categories
# >
# > - Number : Cardianl_NER , {0..9}
# > - Common-number : {123456, 123, 123456789, 12345,1234, 11, 13, 12345678, 01, 10}
# > - Year : Date_NER (filter only the year)
#
# > Specials Categories
# >
# > - Simple : { . _   !   @   -   :   #    *   $   space   &   +   ?   ,   / }
# > - Combined : {!!   .:   &#   **   …   :,   $$  __ }

# %%
#Filter df to only allwoed tags
def filter_df_tags(df_words, allowed_tags):
    tag_dict = {tag: [] for tag in allowed_tags}  # Initialize dictionary with allowed tags

    # Iterate over each row in df_words
    for idx, row in df_words.iterrows():
        word = row['word']
        NER_category = row['NER_category']

        # Check if NER category is allowed
        if NER_category in allowed_tags:
            # Append word to the corresponding category in the dictionary
            tag_dict[NER_category].append(word)

    # Remove duplicates from each list
    for tag in tag_dict:
        tag_dict[tag] = list(set(tag_dict[tag]))

    return tag_dict

#EXAMPLE
allowed_tags = ["GPE", "LOC", "PERSON", "CARDINAL", "DATE"]
filtered_df_words = filter_df_tags(df_words, allowed_tags)
print(filtered_df_words)
# Out:
# {'GPE': [], 'LOC': [], 'PERSON': ['georges', 'harrys'], 'CARDINAL': [], 'DATE': []}

# %%
#Filter neutral ner to only allowed tags
def filter_ner_neutral_tags(ner_neutral, allowed_tags):
    tag_dict = {tag: [] for tag in allowed_tags}  # Initialize dictionary with allowed tags

    # Iterate over each row in NER_neutral
    for idx, row in ner_neutral.iterrows():
        for col in ner_neutral.columns:
            word = row[col]
            if pd.notnull(word):
                # Check if NER category is allowed
                if col in allowed_tags:
                    # Append word to the corresponding category in the dictionary
                    tag_dict[col].append(word)

    # Remove duplicates from each list
    for tag in tag_dict:
        tag_dict[tag] = list(set(tag_dict[tag]))

    return tag_dict

#EXAMPLE
allowed_tags = ["GPE", "LOC", "PERSON", "CARDINAL", "DATE"]
filtered_ner_neutral = filter_ner_neutral_tags(NER_neutral, allowed_tags)
print(filtered_ner_neutral)
# Out:
# {'GPE': ['toulouse'], 'LOC': [], 'PERSON': ['georges', 'harrys'], 'CARDINAL': [], 'DATE': []}

# %% [markdown]
# Build Dictionaries and Lists

# %%
string_dict={}
string_dict['Name'] = list(set(filtered_ner_neutral.get('PERSON', [])) & set(filtered_df_words.get('PERSON', [])))
string_dict
# Out:
# {'Name': ['georges', 'harrys']}

# %%
import itertools

#Create dictionaries
string_dict = {
    'Name': list(set(filtered_ner_neutral.get('PERSON', [])).union(filtered_df_words.get('PERSON', []))),
    'Article': ['I', 'my', 'the', 'it', 'we', 'you'],
    'City': list(set(filtered_ner_neutral.get('GPE', [])).union(filtered_df_words.get('GPE', [])))
    + list(set(filtered_ner_neutral.get('LOC', [])).union(filtered_df_words.get('LOC', []))),
    'Keyboard': ['qwerty', 'qwe', 'abc', 'asd'],
    'Prepositions': ['to', 'in'],
}

digit_dict = {
    'Number': list(set(filtered_ner_neutral.get('CARDINAL', [])).union(filtered_df_words.get('CARDINAL', [])))
    + [str(i) for i in range(10)],
    'Common': ['123456', '123', '123456789', '12345', '1234', '11', '13', '12345678', '01', '10'],
    'Year': [date[-4:] for date in list(set(filtered_ner_neutral.get('DATE', [])).union(filtered_df_words.get('DATE', []))) if date[-4:].isdigit()],
}

special_dict = {
    'Simple': ['.', '_', '!', '@', '-', ':', '#', '*', '$', ' ', '&', '+', '?', ',', '/'],
    'Combined': ['!!', '.:', '&#', '**', '…', ':', '$$', '__'],
}

# Create lists for each dictionary
string_list = list(itertools.chain.from_iterable(string_dict.values()))
digit_list = list(itertools.chain.from_iterable(digit_dict.values()))
special_list = list(itertools.chain.from_iterable(special_dict.values()))

# %% [markdown]
# Generate List of Passwords

# %%
def generate_passwords(strings, digits, specials):
    all_combinations = []

    # Generate combinations of string + special + digits
    combo1 = itertools.product(strings, specials, digits)
    all_combinations.extend(''.join(comb) for comb in combo1)

    # Generate combinations of string + digits + special
    combo2 = itertools.product(strings, digits, specials)
    all_combinations.extend(''.join(comb) for comb in combo2)

    # Filter combinations with length >= 8
    valid_passwords = [password for password in all_combinations if len(password) >= 8]

    return valid_passwords

password_combinations = generate_passwords(string_list, digit_list, special_list)

print("Generated Password Combinations:")
i = 0
for password in password_combinations:
    print(i , ' : ' , password)
    i+=1
# Out:
# Streaming output truncated to the last 5000 lines.
# 1020  :  my#123456789
# 1021  :  my#12345
# 1022  :  my#12345678
# 1023  :  my*123456
# 1024  :  my*123456789
# 1025  :  my*12345
# 1026  :  my*12345678
# 1027  :  my$123456
# 1028  :  my$123456789
# 1029  :  my$12345
# 1030  :  my$12345678
# 1031  :  my 123456
# 1032  :  my 123456789
# 1033  :  my 12345
# 1034  :  my 12345678
# 1035  :  my&123456
# 1036  :  my&123456789
# 1037  :  my&12345
# 1038  :  my&12345678
# 1039  :  my+123456
# 1040  :  my+123456789
# 1041  :  my+12345
# 1042  :  my+12345678
# 1043  :  my?123456
# 1044  :  my?123456789
# 1045  :  my?12345
# 1046  :  my?12345678
# 1047  :  my,123456
# 1048  :  my,123456789
# 1049  :  my,12345
# 1050  :  my,12345678
# 1051  :  my/123456
# 1052  :  my/123456789
# 1053  :  my/12345
# 1054  :  my/12345678
# 1055  :  my!!123456
# 1056  :  my!!123456789
# 1057  :  my!!12345
# 1058  :  my!!1234
# 1059  :  my!!12345678
# 1060  :  my.:123456
# 1061  :  my.:123456789
# 1062  :  my.:12345
# 1063  :  my.:1234
# 1064  :  my.:12345678
# 1065  :  my&#123456
# 1066  :  my&#123456789
# 1067  :  my&#12345
# 1068  :  my&#1234
# 1069  :  my&#12345678
# 1070  :  my**123456
# 1071  :  my**123456789
# 1072  :  my**12345
# 1073  :  my**1234
# 1074  :  my**12345678
# 1075  :  my…123456
# 1076  :  my…123456789
# 1077  :  my…12345
# 1078  :  my…12345678
# 1079  :  my:123456
# 1080  :  my:123456789
# 1081  :  my:12345
# 1082  :  my:12345678
# 1083  :  my$$123456
# 1084  :  my$$123456789
# 1085  :  my$$12345
# 1086  :  my$$1234
# 1087  :  my$$12345678
# 1088  :  my__123456
# 1089  :  my__123456789
# 1090  :  my__12345
# 1091  :  my__1234
# 1092  :  my__12345678
# 1093  :  the.123456
# 1094  :  the.123456789
# 1095  :  the.12345
# 1096  :  the.1234
# 1097  :  the.12345678
# 1098  :  the_123456
# 1099  :  the_123456789
# 1100  :  the_12345
# 1101  :  the_1234
# 1102  :  the_12345678
# 1103  :  the!123456
# 1104  :  the!123456789
# 1105  :  the!12345
# 1106  :  the!1234
# 1107  :  the!12345678
# 1108  :  the@123456
# 1109  :  the@123456789
# 1110  :  the@12345
# 1111  :  the@1234
# 1112  :  the@12345678
# 1113  :  the-123456
# 1114  :  the-123456789
# 1115  :  the-12345
# 1116  :  the-1234
# 1117  :  the-12345678
# 1118  :  the:123456
# 1119  :  the:123456789
# 1120  :  the:12345
# 1121  :  the:1234
# 1122  :  the:12345678
# 1123  :  the#123456
# 1124  :  the#123456789
# 1125  :  the#12345
# 1126  :  the#1234
# 1127  :  the#12345678
# 1128  :  the*123456
# 1129  :  the*123456789
# 1130  :  the*12345
# 1131  :  the*1234
# 1132  :  the*12345678
# 1133  :  the$123456
# 1134  :  the$123456789
# 1135  :  the$12345
# 1136  :  the$1234
# 1137  :  the$12345678
# 1138  :  the 123456
# 1139  :  the 123456789
# 1140  :  the 12345
# 1141  :  the 1234
# 1142  :  the 12345678
# 1143  :  the&123456
# 1144  :  the&123456789
# 1145  :  the&12345
# 1146  :  the&1234
# 1147  :  the&12345678
# 1148  :  the+123456
# 1149  :  the+123456789
# 1150  :  the+12345
# 1151  :  the+1234
# 1152  :  the+12345678
# 1153  :  the?123456
# 1154  :  the?123456789
# 1155  :  the?12345
# 1156  :  the?1234
# 1157  :  the?12345678
# 1158  :  the,123456
# 1159  :  the,123456789
# 1160  :  the,12345
# 1161  :  the,1234
# 1162  :  the,12345678
# 1163  :  the/123456
# 1164  :  the/123456789
# 1165  :  the/12345
# 1166  :  the/1234
# 1167  :  the/12345678
# 1168  :  the!!123456
# 1169  :  the!!123
# 1170  :  the!!123456789
# 1171  :  the!!12345
# 1172  :  the!!1234
# 1173  :  the!!12345678
# 1174  :  the.:123456
# 1175  :  the.:123
# 1176  :  the.:123456789
# 1177  :  the.:12345
# 1178  :  the.:1234
# 1179  :  the.:12345678
# 1180  :  the&#123456
# 1181  :  the&#123
# 1182  :  the&#123456789
# 1183  :  the&#12345
# 1184  :  the&#1234
# 1185  :  the&#12345678
# 1186  :  the**123456
# 1187  :  the**123
# 1188  :  the**123456789
# 1189  :  the**12345
# 1190  :  the**1234
# 1191  :  the**12345678
# 1192  :  the…123456
# 1193  :  the…123456789
# 1194  :  the…12345
# 1195  :  the…1234
# 1196  :  the…12345678
# 1197  :  the:123456
# 1198  :  the:123456789
# 1199  :  the:12345
# 1200  :  the:1234
# 1201  :  the:12345678
# 1202  :  the$$123456
# 1203  :  the$$123
# 1204  :  the$$123456789
# 1205  :  the$$12345
# 1206  :  the$$1234
# 1207  :  the$$12345678
# 1208  :  the__123456
# 1209  :  the__123
# 1210  :  the__123456789
# 1211  :  the__12345
# 1212  :  the__1234
# 1213  :  the__12345678
# 1214  :  it.123456
# 1215  :  it.123456789
# 1216  :  it.12345
# 1217  :  it.12345678
# 1218  :  it_123456
# 1219  :  it_123456789
# 1220  :  it_12345
# 1221  :  it_12345678
# 1222  :  it!123456
# 1223  :  it!123456789
# 1224  :  it!12345
# 1225  :  it!12345678
# 1226  :  it@123456
# 1227  :  it@123456789
# 1228  :  it@12345
# 1229  :  it@12345678
# 1230  :  it-123456
# 1231  :  it-123456789
# 1232  :  it-12345
# 1233  :  it-12345678
# 1234  :  it:123456
# 1235  :  it:123456789
# 1236  :  it:12345
# 1237  :  it:12345678
# 1238  :  it#123456
# 1239  :  it#123456789
# 1240  :  it#12345
# 1241  :  it#12345678
# 1242  :  it*123456
# 1243  :  it*123456789
# 1244  :  it*12345
# 1245  :  it*12345678
# 1246  :  it$123456
# 1247  :  it$123456789
# 1248  :  it$12345
# 1249  :  it$12345678
# 1250  :  it 123456
# 1251  :  it 123456789
# 1252  :  it 12345
# 1253  :  it 12345678
# 1254  :  it&123456
# 1255  :  it&123456789
# 1256  :  it&12345
# 1257  :  it&12345678
# 1258  :  it+123456
# 1259  :  it+123456789
# 1260  :  it+12345
# 1261  :  it+12345678
# 1262  :  it?123456
# 1263  :  it?123456789
# 1264  :  it?12345
# 1265  :  it?12345678
# 1266  :  it,123456
# 1267  :  it,123456789
# 1268  :  it,12345
# 1269  :  it,12345678
# 1270  :  it/123456
# 1271  :  it/123456789
# 1272  :  it/12345
# 1273  :  it/12345678
# 1274  :  it!!123456
# 1275  :  it!!123456789
# 1276  :  it!!12345
# 1277  :  it!!1234
# 1278  :  it!!12345678
# 1279  :  it.:123456
# 1280  :  it.:123456789
# 1281  :  it.:12345
# 1282  :  it.:1234
# 1283  :  it.:12345678
# 1284  :  it&#123456
# 1285  :  it&#123456789
# 1286  :  it&#12345
# 1287  :  it&#1234
# 1288  :  it&#12345678
# 1289  :  it**123456
# 1290  :  it**123456789
# 1291  :  it**12345
# 1292  :  it**1234
# 1293  :  it**12345678
# 1294  :  it…123456
# 1295  :  it…123456789
# 1296  :  it…12345
# 1297  :  it…12345678
# 1298  :  it:123456
# 1299  :  it:123456789
# 1300  :  it:12345
# 1301  :  it:12345678
# 1302  :  it$$123456
# 1303  :  it$$123456789
# 1304  :  it$$12345
# 1305  :  it$$1234
# 1306  :  it$$12345678
# 1307  :  it__123456
# 1308  :  it__123456789
# 1309  :  it__12345
# 1310  :  it__1234
# 1311  :  it__12345678
# 1312  :  we.123456
# 1313  :  we.123456789
# 1314  :  we.12345
# 1315  :  we.12345678
# 1316  :  we_123456
# 1317  :  we_123456789
# 1318  :  we_12345
# 1319  :  we_12345678
# 1320  :  we!123456
# 1321  :  we!123456789
# 1322  :  we!12345
# 1323  :  we!12345678
# 1324  :  we@123456
# 1325  :  we@123456789
# 1326  :  we@12345
# 1327  :  we@12345678
# 1328  :  we-123456
# 1329  :  we-123456789
# 1330  :  we-12345
# 1331  :  we-12345678
# 1332  :  we:123456
# 1333  :  we:123456789
# 1334  :  we:12345
# 1335  :  we:12345678
# 1336  :  we#123456
# 1337  :  we#123456789
# 1338  :  we#12345
# 1339  :  we#12345678
# 1340  :  we*123456
# 1341  :  we*123456789
# 1342  :  we*12345
# 1343  :  we*12345678
# 1344  :  we$123456
# 1345  :  we$123456789
# 1346  :  we$12345
# 1347  :  we$12345678
# 1348  :  we 123456
# 1349  :  we 123456789
# 1350  :  we 12345
# 1351  :  we 12345678
# 1352  :  we&123456
# 1353  :  we&123456789
# 1354  :  we&12345
# 1355  :  we&12345678
# 1356  :  we+123456
# 1357  :  we+123456789
# 1358  :  we+12345
# 1359  :  we+12345678
# 1360  :  we?123456
# 1361  :  we?123456789
# 1362  :  we?12345
# 1363  :  we?12345678
# 1364  :  we,123456
# 1365  :  we,123456789
# 1366  :  we,12345
# 1367  :  we,12345678
# 1368  :  we/123456
# 1369  :  we/123456789
# 1370  :  we/12345
# 1371  :  we/12345678
# 1372  :  we!!123456
# 1373  :  we!!123456789
# 1374  :  we!!12345
# 1375  :  we!!1234
# 1376  :  we!!12345678
# 1377  :  we.:123456
# 1378  :  we.:123456789
# 1379  :  we.:12345
# 1380  :  we.:1234
# 1381  :  we.:12345678
# 1382  :  we&#123456
# 1383  :  we&#123456789
# 1384  :  we&#12345
# 1385  :  we&#1234
# 1386  :  we&#12345678
# 1387  :  we**123456
# 1388  :  we**123456789
# 1389  :  we**12345
# 1390  :  we**1234
# 1391  :  we**12345678
# 1392  :  we…123456
# 1393  :  we…123456789
# 1394  :  we…12345
# 1395  :  we…12345678
# 1396  :  we:123456
# 1397  :  we:123456789
# 1398  :  we:12345
# 1399  :  we:12345678
# 1400  :  we$$123456
# 1401  :  we$$123456789
# 1402  :  we$$12345
# 1403  :  we$$1234
# 1404  :  we$$12345678
# 1405  :  we__123456
# 1406  :  we__123456789
# 1407  :  we__12345
# 1408  :  we__1234
# 1409  :  we__12345678
# 1410  :  you.123456
# 1411  :  you.123456789
# 1412  :  you.12345
# 1413  :  you.1234
# 1414  :  you.12345678
# 1415  :  you_123456
# 1416  :  you_123456789
# 1417  :  you_12345
# 1418  :  you_1234
# 1419  :  you_12345678
# 1420  :  you!123456
# 1421  :  you!123456789
# 1422  :  you!12345
# 1423  :  you!1234
# 1424  :  you!12345678
# 1425  :  you@123456
# 1426  :  you@123456789
# 1427  :  you@12345
# 1428  :  you@1234
# 1429  :  you@12345678
# 1430  :  you-123456
# 1431  :  you-123456789
# 1432  :  you-12345
# 1433  :  you-1234
# 1434  :  you-12345678
# 1435  :  you:123456
# 1436  :  you:123456789
# 1437  :  you:12345
# 1438  :  you:1234
# 1439  :  you:12345678
# 1440  :  you#123456
# 1441  :  you#123456789
# 1442  :  you#12345
# 1443  :  you#1234
# 1444  :  you#12345678
# 1445  :  you*123456
# 1446  :  you*123456789
# 1447  :  you*12345
# 1448  :  you*1234
# 1449  :  you*12345678
# 1450  :  you$123456
# 1451  :  you$123456789
# 1452  :  you$12345
# 1453  :  you$1234
# 1454  :  you$12345678
# 1455  :  you 123456
# 1456  :  you 123456789
# 1457  :  you 12345
# 1458  :  you 1234
# 1459  :  you 12345678
# 1460  :  you&123456
# 1461  :  you&123456789
# 1462  :  you&12345
# 1463  :  you&1234
# 1464  :  you&12345678
# 1465  :  you+123456
# 1466  :  you+123456789
# 1467  :  you+12345
# 1468  :  you+1234
# 1469  :  you+12345678
# 1470  :  you?123456
# 1471  :  you?123456789
# 1472  :  you?12345
# 1473  :  you?1234
# 1474  :  you?12345678
# 1475  :  you,123456
# 1476  :  you,123456789
# 1477  :  you,12345
# 1478  :  you,1234
# 1479  :  you,12345678
# 1480  :  you/123456
# 1481  :  you/123456789
# 1482  :  you/12345
# 1483  :  you/1234
# 1484  :  you/12345678
# 1485  :  you!!123456
# 1486  :  you!!123
# 1487  :  you!!123456789
# 1488  :  you!!12345
# 1489  :  you!!1234
# 1490  :  you!!12345678
# 1491  :  you.:123456
# 1492  :  you.:123
# 1493  :  you.:123456789
# 1494  :  you.:12345
# 1495  :  you.:1234
# 1496  :  you.:12345678
# 1497  :  you&#123456
# 1498  :  you&#123
# 1499  :  you&#123456789
# 1500  :  you&#12345
# 1501  :  you&#1234
# 1502  :  you&#12345678
# 1503  :  you**123456
# 1504  :  you**123
# 1505  :  you**123456789
# 1506  :  you**12345
# 1507  :  you**1234
# 1508  :  you**12345678
# 1509  :  you…123456
# 1510  :  you…123456789
# 1511  :  you…12345
# 1512  :  you…1234
# 1513  :  you…12345678
# 1514  :  you:123456
# 1515  :  you:123456789
# 1516  :  you:12345
# 1517  :  you:1234
# 1518  :  you:12345678
# 1519  :  you$$123456
# 1520  :  you$$123
# 1521  :  you$$123456789
# 1522  :  you$$12345
# 1523  :  you$$1234
# 1524  :  you$$12345678
# 1525  :  you__123456
# 1526  :  you__123
# 1527  :  you__123456789
# 1528  :  you__12345
# 1529  :  you__1234
# 1530  :  you__12345678
# 1531  :  toulouse.0
# 1532  :  toulouse.1
# 1533  :  toulouse.2
# 1534  :  toulouse.3
# 1535  :  toulouse.4
# 1536  :  toulouse.5
# 1537  :  toulouse.6
# 1538  :  toulouse.7
# 1539  :  toulouse.8
# 1540  :  toulouse.9
# 1541  :  toulouse.123456
# 1542  :  toulouse.123
# 1543  :  toulouse.123456789
# 1544  :  toulouse.12345
# 1545  :  toulouse.1234
# 1546  :  toulouse.11
# 1547  :  toulouse.13
# 1548  :  toulouse.12345678
# 1549  :  toulouse.01
# 1550  :  toulouse.10
# 1551  :  toulouse_0
# 1552  :  toulouse_1
# 1553  :  toulouse_2
# 1554  :  toulouse_3
# 1555  :  toulouse_4
# 1556  :  toulouse_5
# 1557  :  toulouse_6
# 1558  :  toulouse_7
# 1559  :  toulouse_8
# 1560  :  toulouse_9
# 1561  :  toulouse_123456
# 1562  :  toulouse_123
# 1563  :  toulouse_123456789
# 1564  :  toulouse_12345
# 1565  :  toulouse_1234
# 1566  :  toulouse_11
# 1567  :  toulouse_13
# 1568  :  toulouse_12345678
# 1569  :  toulouse_01
# 1570  :  toulouse_10
# 1571  :  toulouse!0
# 1572  :  toulouse!1
# 1573  :  toulouse!2
# 1574  :  toulouse!3
# 1575  :  toulouse!4
# 1576  :  toulouse!5
# 1577  :  toulouse!6
# 1578  :  toulouse!7
# 1579  :  toulouse!8
# 1580  :  toulouse!9
# 1581  :  toulouse!123456
# 1582  :  toulouse!123
# 1583  :  toulouse!123456789
# 1584  :  toulouse!12345
# 1585  :  toulouse!1234
# 1586  :  toulouse!11
# 1587  :  toulouse!13
# 1588  :  toulouse!12345678
# 1589  :  toulouse!01
# 1590  :  toulouse!10
# 1591  :  toulouse@0
# 1592  :  toulouse@1
# 1593  :  toulouse@2
# 1594  :  toulouse@3
# 1595  :  toulouse@4
# 1596  :  toulouse@5
# 1597  :  toulouse@6
# 1598  :  toulouse@7
# 1599  :  toulouse@8
# 1600  :  toulouse@9
# 1601  :  toulouse@123456
# 1602  :  toulouse@123
# 1603  :  toulouse@123456789
# 1604  :  toulouse@12345
# 1605  :  toulouse@1234
# 1606  :  toulouse@11
# 1607  :  toulouse@13
# 1608  :  toulouse@12345678
# 1609  :  toulouse@01
# 1610  :  toulouse@10
# 1611  :  toulouse-0
# 1612  :  toulouse-1
# 1613  :  toulouse-2
# 1614  :  toulouse-3
# 1615  :  toulouse-4
# 1616  :  toulouse-5
# 1617  :  toulouse-6
# 1618  :  toulouse-7
# 1619  :  toulouse-8
# 1620  :  toulouse-9
# 1621  :  toulouse-123456
# 1622  :  toulouse-123
# 1623  :  toulouse-123456789
# 1624  :  toulouse-12345
# 1625  :  toulouse-1234
# 1626  :  toulouse-11
# 1627  :  toulouse-13
# 1628  :  toulouse-12345678
# 1629  :  toulouse-01
# 1630  :  toulouse-10
# 1631  :  toulouse:0
# 1632  :  toulouse:1
# 1633  :  toulouse:2
# 1634  :  toulouse:3
# 1635  :  toulouse:4
# 1636  :  toulouse:5
# 1637  :  toulouse:6
# 1638  :  toulouse:7
# 1639  :  toulouse:8
# 1640  :  toulouse:9
# 1641  :  toulouse:123456
# 1642  :  toulouse:123
# 1643  :  toulouse:123456789
# 1644  :  toulouse:12345
# 1645  :  toulouse:1234
# 1646  :  toulouse:11
# 1647  :  toulouse:13
# 1648  :  toulouse:12345678
# 1649  :  toulouse:01
# 1650  :  toulouse:10
# 1651  :  toulouse#0
# 1652  :  toulouse#1
# 1653  :  toulouse#2
# 1654  :  toulouse#3
# 1655  :  toulouse#4
# 1656  :  toulouse#5
# 1657  :  toulouse#6
# 1658  :  toulouse#7
# 1659  :  toulouse#8
# 1660  :  toulouse#9
# 1661  :  toulouse#123456
# 1662  :  toulouse#123
# 1663  :  toulouse#123456789
# 1664  :  toulouse#12345
# 1665  :  toulouse#1234
# 1666  :  toulouse#11
# 1667  :  toulouse#13
# 1668  :  toulouse#12345678
# 1669  :  toulouse#01
# 1670  :  toulouse#10
# 1671  :  toulouse*0
# 1672  :  toulouse*1
# 1673  :  toulouse*2
# 1674  :  toulouse*3
# 1675  :  toulouse*4
# 1676  :  toulouse*5
# 1677  :  toulouse*6
# 1678  :  toulouse*7
# 1679  :  toulouse*8
# 1680  :  toulouse*9
# 1681  :  toulouse*123456
# 1682  :  toulouse*123
# 1683  :  toulouse*123456789
# 1684  :  toulouse*12345
# 1685  :  toulouse*1234
# 1686  :  toulouse*11
# 1687  :  toulouse*13
# 1688  :  toulouse*12345678
# 1689  :  toulouse*01
# 1690  :  toulouse*10
# 1691  :  toulouse$0
# 1692  :  toulouse$1
# 1693  :  toulouse$2
# 1694  :  toulouse$3
# 1695  :  toulouse$4
# 1696  :  toulouse$5
# 1697  :  toulouse$6
# 1698  :  toulouse$7
# 1699  :  toulouse$8
# 1700  :  toulouse$9
# 1701  :  toulouse$123456
# 1702  :  toulouse$123
# 1703  :  toulouse$123456789
# 1704  :  toulouse$12345
# 1705  :  toulouse$1234
# 1706  :  toulouse$11
# 1707  :  toulouse$13
# 1708  :  toulouse$12345678
# 1709  :  toulouse$01
# 1710  :  toulouse$10
# 1711  :  toulouse 0
# 1712  :  toulouse 1
# 1713  :  toulouse 2
# 1714  :  toulouse 3
# 1715  :  toulouse 4
# 1716  :  toulouse 5
# 1717  :  toulouse 6
# 1718  :  toulouse 7
# 1719  :  toulouse 8
# 1720  :  toulouse 9
# 1721  :  toulouse 123456
# 1722  :  toulouse 123
# 1723  :  toulouse 123456789
# 1724  :  toulouse 12345
# 1725  :  toulouse 1234
# 1726  :  toulouse 11
# 1727  :  toulouse 13
# 1728  :  toulouse 12345678
# 1729  :  toulouse 01
# 1730  :  toulouse 10
# 1731  :  toulouse&0
# 1732  :  toulouse&1
# 1733  :  toulouse&2
# 1734  :  toulouse&3
# 1735  :  toulouse&4
# 1736  :  toulouse&5
# 1737  :  toulouse&6
# 1738  :  toulouse&7
# 1739  :  toulouse&8
# 1740  :  toulouse&9
# 1741  :  toulouse&123456
# 1742  :  toulouse&123
# 1743  :  toulouse&123456789
# 1744  :  toulouse&12345
# 1745  :  toulouse&1234
# 1746  :  toulouse&11
# 1747  :  toulouse&13
# 1748  :  toulouse&12345678
# 1749  :  toulouse&01
# 1750  :  toulouse&10
# 1751  :  toulouse+0
# 1752  :  toulouse+1
# 1753  :  toulouse+2
# 1754  :  toulouse+3
# 1755  :  toulouse+4
# 1756  :  toulouse+5
# 1757  :  toulouse+6
# 1758  :  toulouse+7
# 1759  :  toulouse+8
# 1760  :  toulouse+9
# 1761  :  toulouse+123456
# 1762  :  toulouse+123
# 1763  :  toulouse+123456789
# 1764  :  toulouse+12345
# 1765  :  toulouse+1234
# 1766  :  toulouse+11
# 1767  :  toulouse+13
# 1768  :  toulouse+12345678
# 1769  :  toulouse+01
# 1770  :  toulouse+10
# 1771  :  toulouse?0
# 1772  :  toulouse?1
# 1773  :  toulouse?2
# 1774  :  toulouse?3
# 1775  :  toulouse?4
# 1776  :  toulouse?5
# 1777  :  toulouse?6
# 1778  :  toulouse?7
# 1779  :  toulouse?8
# 1780  :  toulouse?9
# 1781  :  toulouse?123456
# 1782  :  toulouse?123
# 1783  :  toulouse?123456789
# 1784  :  toulouse?12345
# 1785  :  toulouse?1234
# 1786  :  toulouse?11
# 1787  :  toulouse?13
# 1788  :  toulouse?12345678
# 1789  :  toulouse?01
# 1790  :  toulouse?10
# 1791  :  toulouse,0
# 1792  :  toulouse,1
# 1793  :  toulouse,2
# 1794  :  toulouse,3
# 1795  :  toulouse,4
# 1796  :  toulouse,5
# 1797  :  toulouse,6
# 1798  :  toulouse,7
# 1799  :  toulouse,8
# 1800  :  toulouse,9
# 1801  :  toulouse,123456
# 1802  :  toulouse,123
# 1803  :  toulouse,123456789
# 1804  :  toulouse,12345
# 1805  :  toulouse,1234
# 1806  :  toulouse,11
# 1807  :  toulouse,13
# 1808  :  toulouse,12345678
# 1809  :  toulouse,01
# 1810  :  toulouse,10
# 1811  :  toulouse/0
# 1812  :  toulouse/1
# 1813  :  toulouse/2
# 1814  :  toulouse/3
# 1815  :  toulouse/4
# 1816  :  toulouse/5
# 1817  :  toulouse/6
# 1818  :  toulouse/7
# 1819  :  toulouse/8
# 1820  :  toulouse/9
# 1821  :  toulouse/123456
# 1822  :  toulouse/123
# 1823  :  toulouse/123456789
# 1824  :  toulouse/12345
# 1825  :  toulouse/1234
# 1826  :  toulouse/11
# 1827  :  toulouse/13
# 1828  :  toulouse/12345678
# 1829  :  toulouse/01
# 1830  :  toulouse/10
# 1831  :  toulouse!!0
# 1832  :  toulouse!!1
# 1833  :  toulouse!!2
# 1834  :  toulouse!!3
# 1835  :  toulouse!!4
# 1836  :  toulouse!!5
# 1837  :  toulouse!!6
# 1838  :  toulouse!!7
# 1839  :  toulouse!!8
# 1840  :  toulouse!!9
# 1841  :  toulouse!!123456
# 1842  :  toulouse!!123
# 1843  :  toulouse!!123456789
# 1844  :  toulouse!!12345
# 1845  :  toulouse!!1234
# 1846  :  toulouse!!11
# 1847  :  toulouse!!13
# 1848  :  toulouse!!12345678
# 1849  :  toulouse!!01
# 1850  :  toulouse!!10
# 1851  :  toulouse.:0
# 1852  :  toulouse.:1
# 1853  :  toulouse.:2
# 1854  :  toulouse.:3
# 1855  :  toulouse.:4
# 1856  :  toulouse.:5
# 1857  :  toulouse.:6
# 1858  :  toulouse.:7
# 1859  :  toulouse.:8
# 1860  :  toulouse.:9
# 1861  :  toulouse.:123456
# 1862  :  toulouse.:123
# 1863  :  toulouse.:123456789
# 1864  :  toulouse.:12345
# 1865  :  toulouse.:1234
# 1866  :  toulouse.:11
# 1867  :  toulouse.:13
# 1868  :  toulouse.:12345678
# 1869  :  toulouse.:01
# 1870  :  toulouse.:10
# 1871  :  toulouse&#0
# 1872  :  toulouse&#1
# 1873  :  toulouse&#2
# 1874  :  toulouse&#3
# 1875  :  toulouse&#4
# 1876  :  toulouse&#5
# 1877  :  toulouse&#6
# 1878  :  toulouse&#7
# 1879  :  toulouse&#8
# 1880  :  toulouse&#9
# 1881  :  toulouse&#123456
# 1882  :  toulouse&#123
# 1883  :  toulouse&#123456789
# 1884  :  toulouse&#12345
# 1885  :  toulouse&#1234
# 1886  :  toulouse&#11
# 1887  :  toulouse&#13
# 1888  :  toulouse&#12345678
# 1889  :  toulouse&#01
# 1890  :  toulouse&#10
# 1891  :  toulouse**0
# 1892  :  toulouse**1
# 1893  :  toulouse**2
# 1894  :  toulouse**3
# 1895  :  toulouse**4
# 1896  :  toulouse**5
# 1897  :  toulouse**6
# 1898  :  toulouse**7
# 1899  :  toulouse**8
# 1900  :  toulouse**9
# 1901  :  toulouse**123456
# 1902  :  toulouse**123
# 1903  :  toulouse**123456789
# 1904  :  toulouse**12345
# 1905  :  toulouse**1234
# 1906  :  toulouse**11
# 1907  :  toulouse**13
# 1908  :  toulouse**12345678
# 1909  :  toulouse**01
# 1910  :  toulouse**10
# 1911  :  toulouse…0
# 1912  :  toulouse…1
# 1913  :  toulouse…2
# 1914  :  toulouse…3
# 1915  :  toulouse…4
# 1916  :  toulouse…5
# 1917  :  toulouse…6
# 1918  :  toulouse…7
# 1919  :  toulouse…8
# 1920  :  toulouse…9
# 1921  :  toulouse…123456
# 1922  :  toulouse…123
# 1923  :  toulouse…123456789
# 1924  :  toulouse…12345
# 1925  :  toulouse…1234
# 1926  :  toulouse…11
# 1927  :  toulouse…13
# 1928  :  toulouse…12345678
# 1929  :  toulouse…01
# 1930  :  toulouse…10
# 1931  :  toulouse:0
# 1932  :  toulouse:1
# 1933  :  toulouse:2
# 1934  :  toulouse:3
# 1935  :  toulouse:4
# 1936  :  toulouse:5
# 1937  :  toulouse:6
# 1938  :  toulouse:7
# 1939  :  toulouse:8
# 1940  :  toulouse:9
# 1941  :  toulouse:123456
# 1942  :  toulouse:123
# 1943  :  toulouse:123456789
# 1944  :  toulouse:12345
# 1945  :  toulouse:1234
# 1946  :  toulouse:11
# 1947  :  toulouse:13
# 1948  :  toulouse:12345678
# 1949  :  toulouse:01
# 1950  :  toulouse:10
# 1951  :  toulouse$$0
# 1952  :  toulouse$$1
# 1953  :  toulouse$$2
# 1954  :  toulouse$$3
# 1955  :  toulouse$$4
# 1956  :  toulouse$$5
# 1957  :  toulouse$$6
# 1958  :  toulouse$$7
# 1959  :  toulouse$$8
# 1960  :  toulouse$$9
# 1961  :  toulouse$$123456
# 1962  :  toulouse$$123
# 1963  :  toulouse$$123456789
# 1964  :  toulouse$$12345
# 1965  :  toulouse$$1234
# 1966  :  toulouse$$11
# 1967  :  toulouse$$13
# 1968  :  toulouse$$12345678
# 1969  :  toulouse$$01
# 1970  :  toulouse$$10
# 1971  :  toulouse__0
# 1972  :  toulouse__1
# 1973  :  toulouse__2
# 1974  :  toulouse__3
# 1975  :  toulouse__4
# 1976  :  toulouse__5
# 1977  :  toulouse__6
# 1978  :  toulouse__7
# 1979  :  toulouse__8
# 1980  :  toulouse__9
# 1981  :  toulouse__123456
# 1982  :  toulouse__123
# 1983  :  toulouse__123456789
# 1984  :  toulouse__12345
# 1985  :  toulouse__1234
# 1986  :  toulouse__11
# 1987  :  toulouse__13
# 1988  :  toulouse__12345678
# 1989  :  toulouse__01
# 1990  :  toulouse__10
# 1991  :  qwerty.0
# 1992  :  qwerty.1
# 1993  :  qwerty.2
# 1994  :  qwerty.3
# 1995  :  qwerty.4
# 1996  :  qwerty.5
# 1997  :  qwerty.6
# 1998  :  qwerty.7
# 1999  :  qwerty.8
# 2000  :  qwerty.9
# 2001  :  qwerty.123456
# 2002  :  qwerty.123
# 2003  :  qwerty.123456789
# 2004  :  qwerty.12345
# 2005  :  qwerty.1234
# 2006  :  qwerty.11
# 2007  :  qwerty.13
# 2008  :  qwerty.12345678
# 2009  :  qwerty.01
# 2010  :  qwerty.10
# 2011  :  qwerty_0
# 2012  :  qwerty_1
# 2013  :  qwerty_2
# 2014  :  qwerty_3
# 2015  :  qwerty_4
# 2016  :  qwerty_5
# 2017  :  qwerty_6
# 2018  :  qwerty_7
# 2019  :  qwerty_8
# 2020  :  qwerty_9
# 2021  :  qwerty_123456
# 2022  :  qwerty_123
# 2023  :  qwerty_123456789
# 2024  :  qwerty_12345
# 2025  :  qwerty_1234
# 2026  :  qwerty_11
# 2027  :  qwerty_13
# 2028  :  qwerty_12345678
# 2029  :  qwerty_01
# 2030  :  qwerty_10
# 2031  :  qwerty!0
# 2032  :  qwerty!1
# 2033  :  qwerty!2
# 2034  :  qwerty!3
# 2035  :  qwerty!4
# 2036  :  qwerty!5
# 2037  :  qwerty!6
# 2038  :  qwerty!7
# 2039  :  qwerty!8
# 2040  :  qwerty!9
# 2041  :  qwerty!123456
# 2042  :  qwerty!123
# 2043  :  qwerty!123456789
# 2044  :  qwerty!12345
# 2045  :  qwerty!1234
# 2046  :  qwerty!11
# 2047  :  qwerty!13
# 2048  :  qwerty!12345678
# 2049  :  qwerty!01
# 2050  :  qwerty!10
# 2051  :  qwerty@0
# 2052  :  qwerty@1
# 2053  :  qwerty@2
# 2054  :  qwerty@3
# 2055  :  qwerty@4
# 2056  :  qwerty@5
# 2057  :  qwerty@6
# 2058  :  qwerty@7
# 2059  :  qwerty@8
# 2060  :  qwerty@9
# 2061  :  qwerty@123456
# 2062  :  qwerty@123
# 2063  :  qwerty@123456789
# 2064  :  qwerty@12345
# 2065  :  qwerty@1234
# 2066  :  qwerty@11
# 2067  :  qwerty@13
# 2068  :  qwerty@12345678
# 2069  :  qwerty@01
# 2070  :  qwerty@10
# 2071  :  qwerty-0
# 2072  :  qwerty-1
# 2073  :  qwerty-2
# 2074  :  qwerty-3
# 2075  :  qwerty-4
# 2076  :  qwerty-5
# 2077  :  qwerty-6
# 2078  :  qwerty-7
# 2079  :  qwerty-8
# 2080  :  qwerty-9
# 2081  :  qwerty-123456
# 2082  :  qwerty-123
# 2083  :  qwerty-123456789
# 2084  :  qwerty-12345
# 2085  :  qwerty-1234
# 2086  :  qwerty-11
# 2087  :  qwerty-13
# 2088  :  qwerty-12345678
# 2089  :  qwerty-01
# 2090  :  qwerty-10
# 2091  :  qwerty:0
# 2092  :  qwerty:1
# 2093  :  qwerty:2
# 2094  :  qwerty:3
# 2095  :  qwerty:4
# 2096  :  qwerty:5
# 2097  :  qwerty:6
# 2098  :  qwerty:7
# 2099  :  qwerty:8
# 2100  :  qwerty:9
# 2101  :  qwerty:123456
# 2102  :  qwerty:123
# 2103  :  qwerty:123456789
# 2104  :  qwerty:12345
# 2105  :  qwerty:1234
# 2106  :  qwerty:11
# 2107  :  qwerty:13
# 2108  :  qwerty:12345678
# 2109  :  qwerty:01
# 2110  :  qwerty:10
# 2111  :  qwerty#0
# 2112  :  qwerty#1
# 2113  :  qwerty#2
# 2114  :  qwerty#3
# 2115  :  qwerty#4
# 2116  :  qwerty#5
# 2117  :  qwerty#6
# 2118  :  qwerty#7
# 2119  :  qwerty#8
# 2120  :  qwerty#9
# 2121  :  qwerty#123456
# 2122  :  qwerty#123
# 2123  :  qwerty#123456789
# 2124  :  qwerty#12345
# 2125  :  qwerty#1234
# 2126  :  qwerty#11
# 2127  :  qwerty#13
# 2128  :  qwerty#12345678
# 2129  :  qwerty#01
# 2130  :  qwerty#10
# 2131  :  qwerty*0
# 2132  :  qwerty*1
# 2133  :  qwerty*2
# 2134  :  qwerty*3
# 2135  :  qwerty*4
# 2136  :  qwerty*5
# 2137  :  qwerty*6
# 2138  :  qwerty*7
# 2139  :  qwerty*8
# 2140  :  qwerty*9
# 2141  :  qwerty*123456
# 2142  :  qwerty*123
# 2143  :  qwerty*123456789
# 2144  :  qwerty*12345
# 2145  :  qwerty*1234
# 2146  :  qwerty*11
# 2147  :  qwerty*13
# 2148  :  qwerty*12345678
# 2149  :  qwerty*01
# 2150  :  qwerty*10
# 2151  :  qwerty$0
# 2152  :  qwerty$1
# 2153  :  qwerty$2
# 2154  :  qwerty$3
# 2155  :  qwerty$4
# 2156  :  qwerty$5
# 2157  :  qwerty$6
# 2158  :  qwerty$7
# 2159  :  qwerty$8
# 2160  :  qwerty$9
# 2161  :  qwerty$123456
# 2162  :  qwerty$123
# 2163  :  qwerty$123456789
# 2164  :  qwerty$12345
# 2165  :  qwerty$1234
# 2166  :  qwerty$11
# 2167  :  qwerty$13
# 2168  :  qwerty$12345678
# 2169  :  qwerty$01
# 2170  :  qwerty$10
# 2171  :  qwerty 0
# 2172  :  qwerty 1
# 2173  :  qwerty 2
# 2174  :  qwerty 3
# 2175  :  qwerty 4
# 2176  :  qwerty 5
# 2177  :  qwerty 6
# 2178  :  qwerty 7
# 2179  :  qwerty 8
# 2180  :  qwerty 9
# 2181  :  qwerty 123456
# 2182  :  qwerty 123
# 2183  :  qwerty 123456789
# 2184  :  qwerty 12345
# 2185  :  qwerty 1234
# 2186  :  qwerty 11
# 2187  :  qwerty 13
# 2188  :  qwerty 12345678
# 2189  :  qwerty 01
# 2190  :  qwerty 10
# 2191  :  qwerty&0
# 2192  :  qwerty&1
# 2193  :  qwerty&2
# 2194  :  qwerty&3
# 2195  :  qwerty&4
# 2196  :  qwerty&5
# 2197  :  qwerty&6
# 2198  :  qwerty&7
# 2199  :  qwerty&8
# 2200  :  qwerty&9
# 2201  :  qwerty&123456
# 2202  :  qwerty&123
# 2203  :  qwerty&123456789
# 2204  :  qwerty&12345
# 2205  :  qwerty&1234
# 2206  :  qwerty&11
# 2207  :  qwerty&13
# 2208  :  qwerty&12345678
# 2209  :  qwerty&01
# 2210  :  qwerty&10
# 2211  :  qwerty+0
# 2212  :  qwerty+1
# 2213  :  qwerty+2
# 2214  :  qwerty+3
# 2215  :  qwerty+4
# 2216  :  qwerty+5
# 2217  :  qwerty+6
# 2218  :  qwerty+7
# 2219  :  qwerty+8
# 2220  :  qwerty+9
# 2221  :  qwerty+123456
# 2222  :  qwerty+123
# 2223  :  qwerty+123456789
# 2224  :  qwerty+12345
# 2225  :  qwerty+1234
# 2226  :  qwerty+11
# 2227  :  qwerty+13
# 2228  :  qwerty+12345678
# 2229  :  qwerty+01
# 2230  :  qwerty+10
# 2231  :  qwerty?0
# 2232  :  qwerty?1
# 2233  :  qwerty?2
# 2234  :  qwerty?3
# 2235  :  qwerty?4
# 2236  :  qwerty?5
# 2237  :  qwerty?6
# 2238  :  qwerty?7
# 2239  :  qwerty?8
# 2240  :  qwerty?9
# 2241  :  qwerty?123456
# 2242  :  qwerty?123
# 2243  :  qwerty?123456789
# 2244  :  qwerty?12345
# 2245  :  qwerty?1234
# 2246  :  qwerty?11
# 2247  :  qwerty?13
# 2248  :  qwerty?12345678
# 2249  :  qwerty?01
# 2250  :  qwerty?10
# 2251  :  qwerty,0
# 2252  :  qwerty,1
# 2253  :  qwerty,2
# 2254  :  qwerty,3
# 2255  :  qwerty,4
# 2256  :  qwerty,5
# 2257  :  qwerty,6
# 2258  :  qwerty,7
# 2259  :  qwerty,8
# 2260  :  qwerty,9
# 2261  :  qwerty,123456
# 2262  :  qwerty,123
# 2263  :  qwerty,123456789
# 2264  :  qwerty,12345
# 2265  :  qwerty,1234
# 2266  :  qwerty,11
# 2267  :  qwerty,13
# 2268  :  qwerty,12345678
# 2269  :  qwerty,01
# 2270  :  qwerty,10
# 2271  :  qwerty/0
# 2272  :  qwerty/1
# 2273  :  qwerty/2
# 2274  :  qwerty/3
# 2275  :  qwerty/4
# 2276  :  qwerty/5
# 2277  :  qwerty/6
# 2278  :  qwerty/7
# 2279  :  qwerty/8
# 2280  :  qwerty/9
# 2281  :  qwerty/123456
# 2282  :  qwerty/123
# 2283  :  qwerty/123456789
# 2284  :  qwerty/12345
# 2285  :  qwerty/1234
# 2286  :  qwerty/11
# 2287  :  qwerty/13
# 2288  :  qwerty/12345678
# 2289  :  qwerty/01
# 2290  :  qwerty/10
# 2291  :  qwerty!!0
# 2292  :  qwerty!!1
# 2293  :  qwerty!!2
# 2294  :  qwerty!!3
# 2295  :  qwerty!!4
# 2296  :  qwerty!!5
# 2297  :  qwerty!!6
# 2298  :  qwerty!!7
# 2299  :  qwerty!!8
# 2300  :  qwerty!!9
# 2301  :  qwerty!!123456
# 2302  :  qwerty!!123
# 2303  :  qwerty!!123456789
# 2304  :  qwerty!!12345
# 2305  :  qwerty!!1234
# 2306  :  qwerty!!11
# 2307  :  qwerty!!13
# 2308  :  qwerty!!12345678
# 2309  :  qwerty!!01
# 2310  :  qwerty!!10
# 2311  :  qwerty.:0
# 2312  :  qwerty.:1
# 2313  :  qwerty.:2
# 2314  :  qwerty.:3
# 2315  :  qwerty.:4
# 2316  :  qwerty.:5
# 2317  :  qwerty.:6
# 2318  :  qwerty.:7
# 2319  :  qwerty.:8
# 2320  :  qwerty.:9
# 2321  :  qwerty.:123456
# 2322  :  qwerty.:123
# 2323  :  qwerty.:123456789
# 2324  :  qwerty.:12345
# 2325  :  qwerty.:1234
# 2326  :  qwerty.:11
# 2327  :  qwerty.:13
# 2328  :  qwerty.:12345678
# 2329  :  qwerty.:01
# 2330  :  qwerty.:10
# 2331  :  qwerty&#0
# 2332  :  qwerty&#1
# 2333  :  qwerty&#2
# 2334  :  qwerty&#3
# 2335  :  qwerty&#4
# 2336  :  qwerty&#5
# 2337  :  qwerty&#6
# 2338  :  qwerty&#7
# 2339  :  qwerty&#8
# 2340  :  qwerty&#9
# 2341  :  qwerty&#123456
# 2342  :  qwerty&#123
# 2343  :  qwerty&#123456789
# 2344  :  qwerty&#12345
# 2345  :  qwerty&#1234
# 2346  :  qwerty&#11
# 2347  :  qwerty&#13
# 2348  :  qwerty&#12345678
# 2349  :  qwerty&#01
# 2350  :  qwerty&#10
# 2351  :  qwerty**0
# 2352  :  qwerty**1
# 2353  :  qwerty**2
# 2354  :  qwerty**3
# 2355  :  qwerty**4
# 2356  :  qwerty**5
# 2357  :  qwerty**6
# 2358  :  qwerty**7
# 2359  :  qwerty**8
# 2360  :  qwerty**9
# 2361  :  qwerty**123456
# 2362  :  qwerty**123
# 2363  :  qwerty**123456789
# 2364  :  qwerty**12345
# 2365  :  qwerty**1234
# 2366  :  qwerty**11
# 2367  :  qwerty**13
# 2368  :  qwerty**12345678
# 2369  :  qwerty**01
# 2370  :  qwerty**10
# 2371  :  qwerty…0
# 2372  :  qwerty…1
# 2373  :  qwerty…2
# 2374  :  qwerty…3
# 2375  :  qwerty…4
# 2376  :  qwerty…5
# 2377  :  qwerty…6
# 2378  :  qwerty…7
# 2379  :  qwerty…8
# 2380  :  qwerty…9
# 2381  :  qwerty…123456
# 2382  :  qwerty…123
# 2383  :  qwerty…123456789
# 2384  :  qwerty…12345
# 2385  :  qwerty…1234
# 2386  :  qwerty…11
# 2387  :  qwerty…13
# 2388  :  qwerty…12345678
# 2389  :  qwerty…01
# 2390  :  qwerty…10
# 2391  :  qwerty:0
# 2392  :  qwerty:1
# 2393  :  qwerty:2
# 2394  :  qwerty:3
# 2395  :  qwerty:4
# 2396  :  qwerty:5
# 2397  :  qwerty:6
# 2398  :  qwerty:7
# 2399  :  qwerty:8
# 2400  :  qwerty:9
# 2401  :  qwerty:123456
# 2402  :  qwerty:123
# 2403  :  qwerty:123456789
# 2404  :  qwerty:12345
# 2405  :  qwerty:1234
# 2406  :  qwerty:11
# 2407  :  qwerty:13
# 2408  :  qwerty:12345678
# 2409  :  qwerty:01
# 2410  :  qwerty:10
# 2411  :  qwerty$$0
# 2412  :  qwerty$$1
# 2413  :  qwerty$$2
# 2414  :  qwerty$$3
# 2415  :  qwerty$$4
# 2416  :  qwerty$$5
# 2417  :  qwerty$$6
# 2418  :  qwerty$$7
# 2419  :  qwerty$$8
# 2420  :  qwerty$$9
# 2421  :  qwerty$$123456
# 2422  :  qwerty$$123
# 2423  :  qwerty$$123456789
# 2424  :  qwerty$$12345
# 2425  :  qwerty$$1234
# 2426  :  qwerty$$11
# 2427  :  qwerty$$13
# 2428  :  qwerty$$12345678
# 2429  :  qwerty$$01
# 2430  :  qwerty$$10
# 2431  :  qwerty__0
# 2432  :  qwerty__1
# 2433  :  qwerty__2
# 2434  :  qwerty__3
# 2435  :  qwerty__4
# 2436  :  qwerty__5
# 2437  :  qwerty__6
# 2438  :  qwerty__7
# 2439  :  qwerty__8
# 2440  :  qwerty__9
# 2441  :  qwerty__123456
# 2442  :  qwerty__123
# 2443  :  qwerty__123456789
# 2444  :  qwerty__12345
# 2445  :  qwerty__1234
# 2446  :  qwerty__11
# 2447  :  qwerty__13
# 2448  :  qwerty__12345678
# 2449  :  qwerty__01
# 2450  :  qwerty__10
# 2451  :  qwe.123456
# 2452  :  qwe.123456789
# 2453  :  qwe.12345
# 2454  :  qwe.1234
# 2455  :  qwe.12345678
# 2456  :  qwe_123456
# 2457  :  qwe_123456789
# 2458  :  qwe_12345
# 2459  :  qwe_1234
# 2460  :  qwe_12345678
# 2461  :  qwe!123456
# 2462  :  qwe!123456789
# 2463  :  qwe!12345
# 2464  :  qwe!1234
# 2465  :  qwe!12345678
# 2466  :  qwe@123456
# 2467  :  qwe@123456789
# 2468  :  qwe@12345
# 2469  :  qwe@1234
# 2470  :  qwe@12345678
# 2471  :  qwe-123456
# 2472  :  qwe-123456789
# 2473  :  qwe-12345
# 2474  :  qwe-1234
# 2475  :  qwe-12345678
# 2476  :  qwe:123456
# 2477  :  qwe:123456789
# 2478  :  qwe:12345
# 2479  :  qwe:1234
# 2480  :  qwe:12345678
# 2481  :  qwe#123456
# 2482  :  qwe#123456789
# 2483  :  qwe#12345
# 2484  :  qwe#1234
# 2485  :  qwe#12345678
# 2486  :  qwe*123456
# 2487  :  qwe*123456789
# 2488  :  qwe*12345
# 2489  :  qwe*1234
# 2490  :  qwe*12345678
# 2491  :  qwe$123456
# 2492  :  qwe$123456789
# 2493  :  qwe$12345
# 2494  :  qwe$1234
# 2495  :  qwe$12345678
# 2496  :  qwe 123456
# 2497  :  qwe 123456789
# 2498  :  qwe 12345
# 2499  :  qwe 1234
# 2500  :  qwe 12345678
# 2501  :  qwe&123456
# 2502  :  qwe&123456789
# 2503  :  qwe&12345
# 2504  :  qwe&1234
# 2505  :  qwe&12345678
# 2506  :  qwe+123456
# 2507  :  qwe+123456789
# 2508  :  qwe+12345
# 2509  :  qwe+1234
# 2510  :  qwe+12345678
# 2511  :  qwe?123456
# 2512  :  qwe?123456789
# 2513  :  qwe?12345
# 2514  :  qwe?1234
# 2515  :  qwe?12345678
# 2516  :  qwe,123456
# 2517  :  qwe,123456789
# 2518  :  qwe,12345
# 2519  :  qwe,1234
# 2520  :  qwe,12345678
# 2521  :  qwe/123456
# 2522  :  qwe/123456789
# 2523  :  qwe/12345
# 2524  :  qwe/1234
# 2525  :  qwe/12345678
# 2526  :  qwe!!123456
# 2527  :  qwe!!123
# 2528  :  qwe!!123456789
# 2529  :  qwe!!12345
# 2530  :  qwe!!1234
# 2531  :  qwe!!12345678
# 2532  :  qwe.:123456
# 2533  :  qwe.:123
# 2534  :  qwe.:123456789
# 2535  :  qwe.:12345
# 2536  :  qwe.:1234
# 2537  :  qwe.:12345678
# 2538  :  qwe&#123456
# 2539  :  qwe&#123
# 2540  :  qwe&#123456789
# 2541  :  qwe&#12345
# 2542  :  qwe&#1234
# 2543  :  qwe&#12345678
# 2544  :  qwe**123456
# 2545  :  qwe**123
# 2546  :  qwe**123456789
# 2547  :  qwe**12345
# 2548  :  qwe**1234
# 2549  :  qwe**12345678
# 2550  :  qwe…123456
# 2551  :  qwe…123456789
# 2552  :  qwe…12345
# 2553  :  qwe…1234
# 2554  :  qwe…12345678
# 2555  :  qwe:123456
# 2556  :  qwe:123456789
# 2557  :  qwe:12345
# 2558  :  qwe:1234
# 2559  :  qwe:12345678
# 2560  :  qwe$$123456
# 2561  :  qwe$$123
# 2562  :  qwe$$123456789
# 2563  :  qwe$$12345
# 2564  :  qwe$$1234
# 2565  :  qwe$$12345678
# 2566  :  qwe__123456
# 2567  :  qwe__123
# 2568  :  qwe__123456789
# 2569  :  qwe__12345
# 2570  :  qwe__1234
# 2571  :  qwe__12345678
# 2572  :  abc.123456
# 2573  :  abc.123456789
# 2574  :  abc.12345
# 2575  :  abc.1234
# 2576  :  abc.12345678
# 2577  :  abc_123456
# 2578  :  abc_123456789
# 2579  :  abc_12345
# 2580  :  abc_1234
# 2581  :  abc_12345678
# 2582  :  abc!123456
# 2583  :  abc!123456789
# 2584  :  abc!12345
# 2585  :  abc!1234
# 2586  :  abc!12345678
# 2587  :  abc@123456
# 2588  :  abc@123456789
# 2589  :  abc@12345
# 2590  :  abc@1234
# 2591  :  abc@12345678
# 2592  :  abc-123456
# 2593  :  abc-123456789
# 2594  :  abc-12345
# 2595  :  abc-1234
# 2596  :  abc-12345678
# 2597  :  abc:123456
# 2598  :  abc:123456789
# 2599  :  abc:12345
# 2600  :  abc:1234
# 2601  :  abc:12345678
# 2602  :  abc#123456
# 2603  :  abc#123456789
# 2604  :  abc#12345
# 2605  :  abc#1234
# 2606  :  abc#12345678
# 2607  :  abc*123456
# 2608  :  abc*123456789
# 2609  :  abc*12345
# 2610  :  abc*1234
# 2611  :  abc*12345678
# 2612  :  abc$123456
# 2613  :  abc$123456789
# 2614  :  abc$12345
# 2615  :  abc$1234
# 2616  :  abc$12345678
# 2617  :  abc 123456
# 2618  :  abc 123456789
# 2619  :  abc 12345
# 2620  :  abc 1234
# 2621  :  abc 12345678
# 2622  :  abc&123456
# 2623  :  abc&123456789
# 2624  :  abc&12345
# 2625  :  abc&1234
# 2626  :  abc&12345678
# 2627  :  abc+123456
# 2628  :  abc+123456789
# 2629  :  abc+12345
# 2630  :  abc+1234
# 2631  :  abc+12345678
# 2632  :  abc?123456
# 2633  :  abc?123456789
# 2634  :  abc?12345
# 2635  :  abc?1234
# 2636  :  abc?12345678
# 2637  :  abc,123456
# 2638  :  abc,123456789
# 2639  :  abc,12345
# 2640  :  abc,1234
# 2641  :  abc,12345678
# 2642  :  abc/123456
# 2643  :  abc/123456789
# 2644  :  abc/12345
# 2645  :  abc/1234
# 2646  :  abc/12345678
# 2647  :  abc!!123456
# 2648  :  abc!!123
# 2649  :  abc!!123456789
# 2650  :  abc!!12345
# 2651  :  abc!!1234
# 2652  :  abc!!12345678
# 2653  :  abc.:123456
# 2654  :  abc.:123
# 2655  :  abc.:123456789
# 2656  :  abc.:12345
# 2657  :  abc.:1234
# 2658  :  abc.:12345678
# 2659  :  abc&#123456
# 2660  :  abc&#123
# 2661  :  abc&#123456789
# 2662  :  abc&#12345
# 2663  :  abc&#1234
# 2664  :  abc&#12345678
# 2665  :  abc**123456
# 2666  :  abc**123
# 2667  :  abc**123456789
# 2668  :  abc**12345
# 2669  :  abc**1234
# 2670  :  abc**12345678
# 2671  :  abc…123456
# 2672  :  abc…123456789
# 2673  :  abc…12345
# 2674  :  abc…1234
# 2675  :  abc…12345678
# 2676  :  abc:123456
# 2677  :  abc:123456789
# 2678  :  abc:12345
# 2679  :  abc:1234
# 2680  :  abc:12345678
# 2681  :  abc$$123456
# 2682  :  abc$$123
# 2683  :  abc$$123456789
# 2684  :  abc$$12345
# 2685  :  abc$$1234
# 2686  :  abc$$12345678
# 2687  :  abc__123456
# 2688  :  abc__123
# 2689  :  abc__123456789
# 2690  :  abc__12345
# 2691  :  abc__1234
# 2692  :  abc__12345678
# 2693  :  asd.123456
# 2694  :  asd.123456789
# 2695  :  asd.12345
# 2696  :  asd.1234
# 2697  :  asd.12345678
# 2698  :  asd_123456
# 2699  :  asd_123456789
# 2700  :  asd_12345
# 2701  :  asd_1234
# 2702  :  asd_12345678
# 2703  :  asd!123456
# 2704  :  asd!123456789
# 2705  :  asd!12345
# 2706  :  asd!1234
# 2707  :  asd!12345678
# 2708  :  asd@123456
# 2709  :  asd@123456789
# 2710  :  asd@12345
# 2711  :  asd@1234
# 2712  :  asd@12345678
# 2713  :  asd-123456
# 2714  :  asd-123456789
# 2715  :  asd-12345
# 2716  :  asd-1234
# 2717  :  asd-12345678
# 2718  :  asd:123456
# 2719  :  asd:123456789
# 2720  :  asd:12345
# 2721  :  asd:1234
# 2722  :  asd:12345678
# 2723  :  asd#123456
# 2724  :  asd#123456789
# 2725  :  asd#12345
# 2726  :  asd#1234
# 2727  :  asd#12345678
# 2728  :  asd*123456
# 2729  :  asd*123456789
# 2730  :  asd*12345
# 2731  :  asd*1234
# 2732  :  asd*12345678
# 2733  :  asd$123456
# 2734  :  asd$123456789
# 2735  :  asd$12345
# 2736  :  asd$1234
# 2737  :  asd$12345678
# 2738  :  asd 123456
# 2739  :  asd 123456789
# 2740  :  asd 12345
# 2741  :  asd 1234
# 2742  :  asd 12345678
# 2743  :  asd&123456
# 2744  :  asd&123456789
# 2745  :  asd&12345
# 2746  :  asd&1234
# 2747  :  asd&12345678
# 2748  :  asd+123456
# 2749  :  asd+123456789
# 2750  :  asd+12345
# 2751  :  asd+1234
# 2752  :  asd+12345678
# 2753  :  asd?123456
# 2754  :  asd?123456789
# 2755  :  asd?12345
# 2756  :  asd?1234
# 2757  :  asd?12345678
# 2758  :  asd,123456
# 2759  :  asd,123456789
# 2760  :  asd,12345
# 2761  :  asd,1234
# 2762  :  asd,12345678
# 2763  :  asd/123456
# 2764  :  asd/123456789
# 2765  :  asd/12345
# 2766  :  asd/1234
# 2767  :  asd/12345678
# 2768  :  asd!!123456
# 2769  :  asd!!123
# 2770  :  asd!!123456789
# 2771  :  asd!!12345
# 2772  :  asd!!1234
# 2773  :  asd!!12345678
# 2774  :  asd.:123456
# 2775  :  asd.:123
# 2776  :  asd.:123456789
# 2777  :  asd.:12345
# 2778  :  asd.:1234
# 2779  :  asd.:12345678
# 2780  :  asd&#123456
# 2781  :  asd&#123
# 2782  :  asd&#123456789
# 2783  :  asd&#12345
# 2784  :  asd&#1234
# 2785  :  asd&#12345678
# 2786  :  asd**123456
# 2787  :  asd**123
# 2788  :  asd**123456789
# 2789  :  asd**12345
# 2790  :  asd**1234
# 2791  :  asd**12345678
# 2792  :  asd…123456
# 2793  :  asd…123456789
# 2794  :  asd…12345
# 2795  :  asd…1234
# 2796  :  asd…12345678
# 2797  :  asd:123456
# 2798  :  asd:123456789
# 2799  :  asd:12345
# 2800  :  asd:1234
# 2801  :  asd:12345678
# 2802  :  asd$$123456
# 2803  :  asd$$123
# 2804  :  asd$$123456789
# 2805  :  asd$$12345
# 2806  :  asd$$1234
# 2807  :  asd$$12345678
# 2808  :  asd__123456
# 2809  :  asd__123
# 2810  :  asd__123456789
# 2811  :  asd__12345
# 2812  :  asd__1234
# 2813  :  asd__12345678
# 2814  :  to.123456
# 2815  :  to.123456789
# 2816  :  to.12345
# 2817  :  to.12345678
# 2818  :  to_123456
# 2819  :  to_123456789
# 2820  :  to_12345
# 2821  :  to_12345678
# 2822  :  to!123456
# 2823  :  to!123456789
# 2824  :  to!12345
# 2825  :  to!12345678
# 2826  :  to@123456
# 2827  :  to@123456789
# 2828  :  to@12345
# 2829  :  to@12345678
# 2830  :  to-123456
# 2831  :  to-123456789
# 2832  :  to-12345
# 2833  :  to-12345678
# 2834  :  to:123456
# 2835  :  to:123456789
# 2836  :  to:12345
# 2837  :  to:12345678
# 2838  :  to#123456
# 2839  :  to#123456789
# 2840  :  to#12345
# 2841  :  to#12345678
# 2842  :  to*123456
# 2843  :  to*123456789
# 2844  :  to*12345
# 2845  :  to*12345678
# 2846  :  to$123456
# 2847  :  to$123456789
# 2848  :  to$12345
# 2849  :  to$12345678
# 2850  :  to 123456
# 2851  :  to 123456789
# 2852  :  to 12345
# 2853  :  to 12345678
# 2854  :  to&123456
# 2855  :  to&123456789
# 2856  :  to&12345
# 2857  :  to&12345678
# 2858  :  to+123456
# 2859  :  to+123456789
# 2860  :  to+12345
# 2861  :  to+12345678
# 2862  :  to?123456
# 2863  :  to?123456789
# 2864  :  to?12345
# 2865  :  to?12345678
# 2866  :  to,123456
# 2867  :  to,123456789
# 2868  :  to,12345
# 2869  :  to,12345678
# 2870  :  to/123456
# 2871  :  to/123456789
# 2872  :  to/12345
# 2873  :  to/12345678
# 2874  :  to!!123456
# 2875  :  to!!123456789
# 2876  :  to!!12345
# 2877  :  to!!1234
# 2878  :  to!!12345678
# 2879  :  to.:123456
# 2880  :  to.:123456789
# 2881  :  to.:12345
# 2882  :  to.:1234
# 2883  :  to.:12345678
# 2884  :  to&#123456
# 2885  :  to&#123456789
# 2886  :  to&#12345
# 2887  :  to&#1234
# 2888  :  to&#12345678
# 2889  :  to**123456
# 2890  :  to**123456789
# 2891  :  to**12345
# 2892  :  to**1234
# 2893  :  to**12345678
# 2894  :  to…123456
# 2895  :  to…123456789
# 2896  :  to…12345
# 2897  :  to…12345678
# 2898  :  to:123456
# 2899  :  to:123456789
# 2900  :  to:12345
# 2901  :  to:12345678
# 2902  :  to$$123456
# 2903  :  to$$123456789
# 2904  :  to$$12345
# 2905  :  to$$1234
# 2906  :  to$$12345678
# 2907  :  to__123456
# 2908  :  to__123456789
# 2909  :  to__12345
# 2910  :  to__1234
# 2911  :  to__12345678
# 2912  :  in.123456
# 2913  :  in.123456789
# 2914  :  in.12345
# 2915  :  in.12345678
# 2916  :  in_123456
# 2917  :  in_123456789
# 2918  :  in_12345
# 2919  :  in_12345678
# 2920  :  in!123456
# 2921  :  in!123456789
# 2922  :  in!12345
# 2923  :  in!12345678
# 2924  :  in@123456
# 2925  :  in@123456789
# 2926  :  in@12345
# 2927  :  in@12345678
# 2928  :  in-123456
# 2929  :  in-123456789
# 2930  :  in-12345
# 2931  :  in-12345678
# 2932  :  in:123456
# 2933  :  in:123456789
# 2934  :  in:12345
# 2935  :  in:12345678
# 2936  :  in#123456
# 2937  :  in#123456789
# 2938  :  in#12345
# 2939  :  in#12345678
# 2940  :  in*123456
# 2941  :  in*123456789
# 2942  :  in*12345
# 2943  :  in*12345678
# 2944  :  in$123456
# 2945  :  in$123456789
# 2946  :  in$12345
# 2947  :  in$12345678
# 2948  :  in 123456
# 2949  :  in 123456789
# 2950  :  in 12345
# 2951  :  in 12345678
# 2952  :  in&123456
# 2953  :  in&123456789
# 2954  :  in&12345
# 2955  :  in&12345678
# 2956  :  in+123456
# 2957  :  in+123456789
# 2958  :  in+12345
# 2959  :  in+12345678
# 2960  :  in?123456
# 2961  :  in?123456789
# 2962  :  in?12345
# 2963  :  in?12345678
# 2964  :  in,123456
# 2965  :  in,123456789
# 2966  :  in,12345
# 2967  :  in,12345678
# 2968  :  in/123456
# 2969  :  in/123456789
# 2970  :  in/12345
# 2971  :  in/12345678
# 2972  :  in!!123456
# 2973  :  in!!123456789
# 2974  :  in!!12345
# 2975  :  in!!1234
# 2976  :  in!!12345678
# 2977  :  in.:123456
# 2978  :  in.:123456789
# 2979  :  in.:12345
# 2980  :  in.:1234
# 2981  :  in.:12345678
# 2982  :  in&#123456
# 2983  :  in&#123456789
# 2984  :  in&#12345
# 2985  :  in&#1234
# 2986  :  in&#12345678
# 2987  :  in**123456
# 2988  :  in**123456789
# 2989  :  in**12345
# 2990  :  in**1234
# 2991  :  in**12345678
# 2992  :  in…123456
# 2993  :  in…123456789
# 2994  :  in…12345
# 2995  :  in…12345678
# 2996  :  in:123456
# 2997  :  in:123456789
# 2998  :  in:12345
# 2999  :  in:12345678
# 3000  :  in$$123456
# 3001  :  in$$123456789
# 3002  :  in$$12345
# 3003  :  in$$1234
# 3004  :  in$$12345678
# 3005  :  in__123456
# 3006  :  in__123456789
# 3007  :  in__12345
# 3008  :  in__1234
# 3009  :  in__12345678
# 3010  :  georges0.
# 3011  :  georges0_
# 3012  :  georges0!
# 3013  :  georges0@
# 3014  :  georges0-
# 3015  :  georges0:
# 3016  :  georges0#
# 3017  :  georges0*
# 3018  :  georges0$
# 3019  :  georges0
# 3020  :  georges0&
# 3021  :  georges0+
# 3022  :  georges0?
# 3023  :  georges0,
# 3024  :  georges0/
# 3025  :  georges0!!
# 3026  :  georges0.:
# 3027  :  georges0&#
# 3028  :  georges0**
# 3029  :  georges0…
# 3030  :  georges0:
# 3031  :  georges0$$
# 3032  :  georges0__
# 3033  :  georges1.
# 3034  :  georges1_
# 3035  :  georges1!
# 3036  :  georges1@
# 3037  :  georges1-
# 3038  :  georges1:
# 3039  :  georges1#
# 3040  :  georges1*
# 3041  :  georges1$
# 3042  :  georges1
# 3043  :  georges1&
# 3044  :  georges1+
# 3045  :  georges1?
# 3046  :  georges1,
# 3047  :  georges1/
# 3048  :  georges1!!
# 3049  :  georges1.:
# 3050  :  georges1&#
# 3051  :  georges1**
# 3052  :  georges1…
# 3053  :  georges1:
# 3054  :  georges1$$
# 3055  :  georges1__
# 3056  :  georges2.
# 3057  :  georges2_
# 3058  :  georges2!
# 3059  :  georges2@
# 3060  :  georges2-
# 3061  :  georges2:
# 3062  :  georges2#
# 3063  :  georges2*
# 3064  :  georges2$
# 3065  :  georges2
# 3066  :  georges2&
# 3067  :  georges2+
# 3068  :  georges2?
# 3069  :  georges2,
# 3070  :  georges2/
# 3071  :  georges2!!
# 3072  :  georges2.:
# 3073  :  georges2&#
# 3074  :  georges2**
# 3075  :  georges2…
# 3076  :  georges2:
# 3077  :  georges2$$
# 3078  :  georges2__
# 3079  :  georges3.
# 3080  :  georges3_
# 3081  :  georges3!
# 3082  :  georges3@
# 3083  :  georges3-
# 3084  :  georges3:
# 3085  :  georges3#
# 3086  :  georges3*
# 3087  :  georges3$
# 3088  :  georges3
# 3089  :  georges3&
# 3090  :  georges3+
# 3091  :  georges3?
# 3092  :  georges3,
# 3093  :  georges3/
# 3094  :  georges3!!
# 3095  :  georges3.:
# 3096  :  georges3&#
# 3097  :  georges3**
# 3098  :  georges3…
# 3099  :  georges3:
# 3100  :  georges3$$
# 3101  :  georges3__
# 3102  :  georges4.
# 3103  :  georges4_
# 3104  :  georges4!
# 3105  :  georges4@
# 3106  :  georges4-
# 3107  :  georges4:
# 3108  :  georges4#
# 3109  :  georges4*
# 3110  :  georges4$
# 3111  :  georges4
# 3112  :  georges4&
# 3113  :  georges4+
# 3114  :  georges4?
# 3115  :  georges4,
# 3116  :  georges4/
# 3117  :  georges4!!
# 3118  :  georges4.:
# 3119  :  georges4&#
# 3120  :  georges4**
# 3121  :  georges4…
# 3122  :  georges4:
# 3123  :  georges4$$
# 3124  :  georges4__
# 3125  :  georges5.
# 3126  :  georges5_
# 3127  :  georges5!
# 3128  :  georges5@
# 3129  :  georges5-
# 3130  :  georges5:
# 3131  :  georges5#
# 3132  :  georges5*
# 3133  :  georges5$
# 3134  :  georges5
# 3135  :  georges5&
# 3136  :  georges5+
# 3137  :  georges5?
# 3138  :  georges5,
# 3139  :  georges5/
# 3140  :  georges5!!
# 3141  :  georges5.:
# 3142  :  georges5&#
# 3143  :  georges5**
# 3144  :  georges5…
# 3145  :  georges5:
# 3146  :  georges5$$
# 3147  :  georges5__
# 3148  :  georges6.
# 3149  :  georges6_
# 3150  :  georges6!
# 3151  :  georges6@
# 3152  :  georges6-
# 3153  :  georges6:
# 3154  :  georges6#
# 3155  :  georges6*
# 3156  :  georges6$
# 3157  :  georges6
# 3158  :  georges6&
# 3159  :  georges6+
# 3160  :  georges6?
# 3161  :  georges6,
# 3162  :  georges6/
# 3163  :  georges6!!
# 3164  :  georges6.:
# 3165  :  georges6&#
# 3166  :  georges6**
# 3167  :  georges6…
# 3168  :  georges6:
# 3169  :  georges6$$
# 3170  :  georges6__
# 3171  :  georges7.
# 3172  :  georges7_
# 3173  :  georges7!
# 3174  :  georges7@
# 3175  :  georges7-
# 3176  :  georges7:
# 3177  :  georges7#
# 3178  :  georges7*
# 3179  :  georges7$
# 3180  :  georges7
# 3181  :  georges7&
# 3182  :  georges7+
# 3183  :  georges7?
# 3184  :  georges7,
# 3185  :  georges7/
# 3186  :  georges7!!
# 3187  :  georges7.:
# 3188  :  georges7&#
# 3189  :  georges7**
# 3190  :  georges7…
# 3191  :  georges7:
# 3192  :  georges7$$
# 3193  :  georges7__
# 3194  :  georges8.
# 3195  :  georges8_
# 3196  :  georges8!
# 3197  :  georges8@
# 3198  :  georges8-
# 3199  :  georges8:
# 3200  :  georges8#
# 3201  :  georges8*
# 3202  :  georges8$
# 3203  :  georges8
# 3204  :  georges8&
# 3205  :  georges8+
# 3206  :  georges8?
# 3207  :  georges8,
# 3208  :  georges8/
# 3209  :  georges8!!
# 3210  :  georges8.:
# 3211  :  georges8&#
# 3212  :  georges8**
# 3213  :  georges8…
# 3214  :  georges8:
# 3215  :  georges8$$
# 3216  :  georges8__
# 3217  :  georges9.
# 3218  :  georges9_
# 3219  :  georges9!
# 3220  :  georges9@
# 3221  :  georges9-
# 3222  :  georges9:
# 3223  :  georges9#
# 3224  :  georges9*
# 3225  :  georges9$
# 3226  :  georges9
# 3227  :  georges9&
# 3228  :  georges9+
# 3229  :  georges9?
# 3230  :  georges9,
# 3231  :  georges9/
# 3232  :  georges9!!
# 3233  :  georges9.:
# 3234  :  georges9&#
# 3235  :  georges9**
# 3236  :  georges9…
# 3237  :  georges9:
# 3238  :  georges9$$
# 3239  :  georges9__
# 3240  :  georges123456.
# 3241  :  georges123456_
# 3242  :  georges123456!
# 3243  :  georges123456@
# 3244  :  georges123456-
# 3245  :  georges123456:
# 3246  :  georges123456#
# 3247  :  georges123456*
# 3248  :  georges123456$
# 3249  :  georges123456
# 3250  :  georges123456&
# 3251  :  georges123456+
# 3252  :  georges123456?
# 3253  :  georges123456,
# 3254  :  georges123456/
# 3255  :  georges123456!!
# 3256  :  georges123456.:
# 3257  :  georges123456&#
# 3258  :  georges123456**
# 3259  :  georges123456…
# 3260  :  georges123456:
# 3261  :  georges123456$$
# 3262  :  georges123456__
# 3263  :  georges123.
# 3264  :  georges123_
# 3265  :  georges123!
# 3266  :  georges123@
# 3267  :  georges123-
# 3268  :  georges123:
# 3269  :  georges123#
# 3270  :  georges123*
# 3271  :  georges123$
# 3272  :  georges123
# 3273  :  georges123&
# 3274  :  georges123+
# 3275  :  georges123?
# 3276  :  georges123,
# 3277  :  georges123/
# 3278  :  georges123!!
# 3279  :  georges123.:
# 3280  :  georges123&#
# 3281  :  georges123**
# 3282  :  georges123…
# 3283  :  georges123:
# 3284  :  georges123$$
# 3285  :  georges123__
# 3286  :  georges123456789.
# 3287  :  georges123456789_
# 3288  :  georges123456789!
# 3289  :  georges123456789@
# 3290  :  georges123456789-
# 3291  :  georges123456789:
# 3292  :  georges123456789#
# 3293  :  georges123456789*
# 3294  :  georges123456789$
# 3295  :  georges123456789
# 3296  :  georges123456789&
# 3297  :  georges123456789+
# 3298  :  georges123456789?
# 3299  :  georges123456789,
# 3300  :  georges123456789/
# 3301  :  georges123456789!!
# 3302  :  georges123456789.:
# 3303  :  georges123456789&#
# 3304  :  georges123456789**
# 3305  :  georges123456789…
# 3306  :  georges123456789:
# 3307  :  georges123456789$$
# 3308  :  georges123456789__
# 3309  :  georges12345.
# 3310  :  georges12345_
# 3311  :  georges12345!
# 3312  :  georges12345@
# 3313  :  georges12345-
# 3314  :  georges12345:
# 3315  :  georges12345#
# 3316  :  georges12345*
# 3317  :  georges12345$
# 3318  :  georges12345
# 3319  :  georges12345&
# 3320  :  georges12345+
# 3321  :  georges12345?
# 3322  :  georges12345,
# 3323  :  georges12345/
# 3324  :  georges12345!!
# 3325  :  georges12345.:
# 3326  :  georges12345&#
# 3327  :  georges12345**
# 3328  :  georges12345…
# 3329  :  georges12345:
# 3330  :  georges12345$$
# 3331  :  georges12345__
# 3332  :  georges1234.
# 3333  :  georges1234_
# 3334  :  georges1234!
# 3335  :  georges1234@
# 3336  :  georges1234-
# 3337  :  georges1234:
# 3338  :  georges1234#
# 3339  :  georges1234*
# 3340  :  georges1234$
# 3341  :  georges1234
# 3342  :  georges1234&
# 3343  :  georges1234+
# 3344  :  georges1234?
# ...
# 5247  :  qwerty123456.:
# 5248  :  qwerty123456&#
# 5249  :  qwerty123456**
# 5250  :  qwerty123456…
# 5251  :  qwerty123456:
# 5252  :  qwerty123456$$
# 5253  :  qwerty123456__
# 5254  :  qwerty123.
# 5255  :  qwerty123_
# 5256  :  qwerty123!
# 5257  :  qwerty123@
# 5258  :  qwerty123-
# 5259  :  qwerty123:
# 5260  :  qwerty123#
# 5261  :  qwerty123*
# 5262  :  qwerty123$
# 5263  :  qwerty123
# 5264  :  qwerty123&
# 5265  :  qwerty123+
# 5266  :  qwerty123?
# 5267  :  qwerty123,
# 5268  :  qwerty123/
# 5269  :  qwerty123!!
# 5270  :  qwerty123.:
# 5271  :  qwerty123&#
# 5272  :  qwerty123**
# 5273  :  qwerty123…
# 5274  :  qwerty123:
# 5275  :  qwerty123$$
# 5276  :  qwerty123__
# 5277  :  qwerty123456789.
# 5278  :  qwerty123456789_
# 5279  :  qwerty123456789!
# 5280  :  qwerty123456789@
# 5281  :  qwerty123456789-
# 5282  :  qwerty123456789:
# 5283  :  qwerty123456789#
# 5284  :  qwerty123456789*
# 5285  :  qwerty123456789$
# 5286  :  qwerty123456789
# 5287  :  qwerty123456789&
# 5288  :  qwerty123456789+
# 5289  :  qwerty123456789?
# 5290  :  qwerty123456789,
# 5291  :  qwerty123456789/
# 5292  :  qwerty123456789!!
# 5293  :  qwerty123456789.:
# 5294  :  qwerty123456789&#
# 5295  :  qwerty123456789**
# 5296  :  qwerty123456789…
# 5297  :  qwerty123456789:
# 5298  :  qwerty123456789$$
# 5299  :  qwerty123456789__
# 5300  :  qwerty12345.
# 5301  :  qwerty12345_
# 5302  :  qwerty12345!
# 5303  :  qwerty12345@
# 5304  :  qwerty12345-
# 5305  :  qwerty12345:
# 5306  :  qwerty12345#
# 5307  :  qwerty12345*
# 5308  :  qwerty12345$
# 5309  :  qwerty12345
# 5310  :  qwerty12345&
# 5311  :  qwerty12345+
# 5312  :  qwerty12345?
# 5313  :  qwerty12345,
# 5314  :  qwerty12345/
# 5315  :  qwerty12345!!
# 5316  :  qwerty12345.:
# 5317  :  qwerty12345&#
# 5318  :  qwerty12345**
# 5319  :  qwerty12345…
# 5320  :  qwerty12345:
# 5321  :  qwerty12345$$
# 5322  :  qwerty12345__
# 5323  :  qwerty1234.
# 5324  :  qwerty1234_
# 5325  :  qwerty1234!
# 5326  :  qwerty1234@
# 5327  :  qwerty1234-
# 5328  :  qwerty1234:
# 5329  :  qwerty1234#
# 5330  :  qwerty1234*
# 5331  :  qwerty1234$
# 5332  :  qwerty1234
# 5333  :  qwerty1234&
# 5334  :  qwerty1234+
# 5335  :  qwerty1234?
# 5336  :  qwerty1234,
# 5337  :  qwerty1234/
# 5338  :  qwerty1234!!
# 5339  :  qwerty1234.:
# 5340  :  qwerty1234&#
# 5341  :  qwerty1234**
# 5342  :  qwerty1234…
# 5343  :  qwerty1234:
# 5344  :  qwerty1234$$
# 5345  :  qwerty1234__
# 5346  :  qwerty11.
# 5347  :  qwerty11_
# 5348  :  qwerty11!
# 5349  :  qwerty11@
# 5350  :  qwerty11-
# 5351  :  qwerty11:
# 5352  :  qwerty11#
# 5353  :  qwerty11*
# 5354  :  qwerty11$
# 5355  :  qwerty11
# 5356  :  qwerty11&
# 5357  :  qwerty11+
# 5358  :  qwerty11?
# 5359  :  qwerty11,
# 5360  :  qwerty11/
# 5361  :  qwerty11!!
# 5362  :  qwerty11.:
# 5363  :  qwerty11&#
# 5364  :  qwerty11**
# 5365  :  qwerty11…
# 5366  :  qwerty11:
# 5367  :  qwerty11$$
# 5368  :  qwerty11__
# 5369  :  qwerty13.
# 5370  :  qwerty13_
# 5371  :  qwerty13!
# 5372  :  qwerty13@
# 5373  :  qwerty13-
# 5374  :  qwerty13:
# 5375  :  qwerty13#
# 5376  :  qwerty13*
# 5377  :  qwerty13$
# 5378  :  qwerty13
# 5379  :  qwerty13&
# 5380  :  qwerty13+
# 5381  :  qwerty13?
# 5382  :  qwerty13,
# 5383  :  qwerty13/
# 5384  :  qwerty13!!
# 5385  :  qwerty13.:
# 5386  :  qwerty13&#
# 5387  :  qwerty13**
# 5388  :  qwerty13…
# 5389  :  qwerty13:
# 5390  :  qwerty13$$
# 5391  :  qwerty13__
# 5392  :  qwerty12345678.
# 5393  :  qwerty12345678_
# 5394  :  qwerty12345678!
# 5395  :  qwerty12345678@
# 5396  :  qwerty12345678-
# 5397  :  qwerty12345678:
# 5398  :  qwerty12345678#
# 5399  :  qwerty12345678*
# 5400  :  qwerty12345678$
# 5401  :  qwerty12345678
# 5402  :  qwerty12345678&
# 5403  :  qwerty12345678+
# 5404  :  qwerty12345678?
# 5405  :  qwerty12345678,
# 5406  :  qwerty12345678/
# 5407  :  qwerty12345678!!
# 5408  :  qwerty12345678.:
# 5409  :  qwerty12345678&#
# 5410  :  qwerty12345678**
# 5411  :  qwerty12345678…
# 5412  :  qwerty12345678:
# 5413  :  qwerty12345678$$
# 5414  :  qwerty12345678__
# 5415  :  qwerty01.
# 5416  :  qwerty01_
# 5417  :  qwerty01!
# 5418  :  qwerty01@
# 5419  :  qwerty01-
# 5420  :  qwerty01:
# 5421  :  qwerty01#
# 5422  :  qwerty01*
# 5423  :  qwerty01$
# 5424  :  qwerty01
# 5425  :  qwerty01&
# 5426  :  qwerty01+
# 5427  :  qwerty01?
# 5428  :  qwerty01,
# 5429  :  qwerty01/
# 5430  :  qwerty01!!
# 5431  :  qwerty01.:
# 5432  :  qwerty01&#
# 5433  :  qwerty01**
# 5434  :  qwerty01…
# 5435  :  qwerty01:
# 5436  :  qwerty01$$
# 5437  :  qwerty01__
# 5438  :  qwerty10.
# 5439  :  qwerty10_
# 5440  :  qwerty10!
# 5441  :  qwerty10@
# 5442  :  qwerty10-
# 5443  :  qwerty10:
# 5444  :  qwerty10#
# 5445  :  qwerty10*
# 5446  :  qwerty10$
# 5447  :  qwerty10
# 5448  :  qwerty10&
# 5449  :  qwerty10+
# 5450  :  qwerty10?
# 5451  :  qwerty10,
# 5452  :  qwerty10/
# 5453  :  qwerty10!!
# 5454  :  qwerty10.:
# 5455  :  qwerty10&#
# 5456  :  qwerty10**
# 5457  :  qwerty10…
# 5458  :  qwerty10:
# 5459  :  qwerty10$$
# 5460  :  qwerty10__
# 5461  :  qwe123456.
# 5462  :  qwe123456_
# 5463  :  qwe123456!
# 5464  :  qwe123456@
# 5465  :  qwe123456-
# 5466  :  qwe123456:
# 5467  :  qwe123456#
# 5468  :  qwe123456*
# 5469  :  qwe123456$
# 5470  :  qwe123456
# 5471  :  qwe123456&
# 5472  :  qwe123456+
# 5473  :  qwe123456?
# 5474  :  qwe123456,
# 5475  :  qwe123456/
# 5476  :  qwe123456!!
# 5477  :  qwe123456.:
# 5478  :  qwe123456&#
# 5479  :  qwe123456**
# 5480  :  qwe123456…
# 5481  :  qwe123456:
# 5482  :  qwe123456$$
# 5483  :  qwe123456__
# 5484  :  qwe123!!
# 5485  :  qwe123.:
# 5486  :  qwe123&#
# 5487  :  qwe123**
# 5488  :  qwe123$$
# 5489  :  qwe123__
# 5490  :  qwe123456789.
# 5491  :  qwe123456789_
# 5492  :  qwe123456789!
# 5493  :  qwe123456789@
# 5494  :  qwe123456789-
# 5495  :  qwe123456789:
# 5496  :  qwe123456789#
# 5497  :  qwe123456789*
# 5498  :  qwe123456789$
# 5499  :  qwe123456789
# 5500  :  qwe123456789&
# 5501  :  qwe123456789+
# 5502  :  qwe123456789?
# 5503  :  qwe123456789,
# 5504  :  qwe123456789/
# 5505  :  qwe123456789!!
# 5506  :  qwe123456789.:
# 5507  :  qwe123456789&#
# 5508  :  qwe123456789**
# 5509  :  qwe123456789…
# 5510  :  qwe123456789:
# 5511  :  qwe123456789$$
# 5512  :  qwe123456789__
# 5513  :  qwe12345.
# 5514  :  qwe12345_
# 5515  :  qwe12345!
# 5516  :  qwe12345@
# 5517  :  qwe12345-
# 5518  :  qwe12345:
# 5519  :  qwe12345#
# 5520  :  qwe12345*
# 5521  :  qwe12345$
# 5522  :  qwe12345
# 5523  :  qwe12345&
# 5524  :  qwe12345+
# 5525  :  qwe12345?
# 5526  :  qwe12345,
# 5527  :  qwe12345/
# 5528  :  qwe12345!!
# 5529  :  qwe12345.:
# 5530  :  qwe12345&#
# 5531  :  qwe12345**
# 5532  :  qwe12345…
# 5533  :  qwe12345:
# 5534  :  qwe12345$$
# 5535  :  qwe12345__
# 5536  :  qwe1234.
# 5537  :  qwe1234_
# 5538  :  qwe1234!
# 5539  :  qwe1234@
# 5540  :  qwe1234-
# 5541  :  qwe1234:
# 5542  :  qwe1234#
# 5543  :  qwe1234*
# 5544  :  qwe1234$
# 5545  :  qwe1234
# 5546  :  qwe1234&
# 5547  :  qwe1234+
# 5548  :  qwe1234?
# 5549  :  qwe1234,
# 5550  :  qwe1234/
# 5551  :  qwe1234!!
# 5552  :  qwe1234.:
# 5553  :  qwe1234&#
# 5554  :  qwe1234**
# 5555  :  qwe1234…
# 5556  :  qwe1234:
# 5557  :  qwe1234$$
# 5558  :  qwe1234__
# 5559  :  qwe12345678.
# 5560  :  qwe12345678_
# 5561  :  qwe12345678!
# 5562  :  qwe12345678@
# 5563  :  qwe12345678-
# 5564  :  qwe12345678:
# 5565  :  qwe12345678#
# 5566  :  qwe12345678*
# 5567  :  qwe12345678$
# 5568  :  qwe12345678
# 5569  :  qwe12345678&
# 5570  :  qwe12345678+
# 5571  :  qwe12345678?
# 5572  :  qwe12345678,
# 5573  :  qwe12345678/
# 5574  :  qwe12345678!!
# 5575  :  qwe12345678.:
# 5576  :  qwe12345678&#
# 5577  :  qwe12345678**
# 5578  :  qwe12345678…
# 5579  :  qwe12345678:
# 5580  :  qwe12345678$$
# 5581  :  qwe12345678__
# 5582  :  abc123456.
# 5583  :  abc123456_
# 5584  :  abc123456!
# 5585  :  abc123456@
# 5586  :  abc123456-
# 5587  :  abc123456:
# 5588  :  abc123456#
# 5589  :  abc123456*
# 5590  :  abc123456$
# 5591  :  abc123456
# 5592  :  abc123456&
# 5593  :  abc123456+
# 5594  :  abc123456?
# 5595  :  abc123456,
# 5596  :  abc123456/
# 5597  :  abc123456!!
# 5598  :  abc123456.:
# 5599  :  abc123456&#
# 5600  :  abc123456**
# 5601  :  abc123456…
# 5602  :  abc123456:
# 5603  :  abc123456$$
# 5604  :  abc123456__
# 5605  :  abc123!!
# 5606  :  abc123.:
# 5607  :  abc123&#
# 5608  :  abc123**
# 5609  :  abc123$$
# 5610  :  abc123__
# 5611  :  abc123456789.
# 5612  :  abc123456789_
# 5613  :  abc123456789!
# 5614  :  abc123456789@
# 5615  :  abc123456789-
# 5616  :  abc123456789:
# 5617  :  abc123456789#
# 5618  :  abc123456789*
# 5619  :  abc123456789$
# 5620  :  abc123456789
# 5621  :  abc123456789&
# 5622  :  abc123456789+
# 5623  :  abc123456789?
# 5624  :  abc123456789,
# 5625  :  abc123456789/
# 5626  :  abc123456789!!
# 5627  :  abc123456789.:
# 5628  :  abc123456789&#
# 5629  :  abc123456789**
# 5630  :  abc123456789…
# 5631  :  abc123456789:
# 5632  :  abc123456789$$
# 5633  :  abc123456789__
# 5634  :  abc12345.
# 5635  :  abc12345_
# 5636  :  abc12345!
# 5637  :  abc12345@
# 5638  :  abc12345-
# 5639  :  abc12345:
# 5640  :  abc12345#
# 5641  :  abc12345*
# 5642  :  abc12345$
# 5643  :  abc12345
# 5644  :  abc12345&
# 5645  :  abc12345+
# 5646  :  abc12345?
# 5647  :  abc12345,
# 5648  :  abc12345/
# 5649  :  abc12345!!
# 5650  :  abc12345.:
# 5651  :  abc12345&#
# 5652  :  abc12345**
# 5653  :  abc12345…
# 5654  :  abc12345:
# 5655  :  abc12345$$
# 5656  :  abc12345__
# 5657  :  abc1234.
# 5658  :  abc1234_
# 5659  :  abc1234!
# 5660  :  abc1234@
# 5661  :  abc1234-
# 5662  :  abc1234:
# 5663  :  abc1234#
# 5664  :  abc1234*
# 5665  :  abc1234$
# 5666  :  abc1234
# 5667  :  abc1234&
# 5668  :  abc1234+
# 5669  :  abc1234?
# 5670  :  abc1234,
# 5671  :  abc1234/
# 5672  :  abc1234!!
# 5673  :  abc1234.:
# 5674  :  abc1234&#
# 5675  :  abc1234**
# 5676  :  abc1234…
# 5677  :  abc1234:
# 5678  :  abc1234$$
# 5679  :  abc1234__
# 5680  :  abc12345678.
# 5681  :  abc12345678_
# 5682  :  abc12345678!
# 5683  :  abc12345678@
# 5684  :  abc12345678-
# 5685  :  abc12345678:
# 5686  :  abc12345678#
# 5687  :  abc12345678*
# 5688  :  abc12345678$
# 5689  :  abc12345678
# 5690  :  abc12345678&
# 5691  :  abc12345678+
# 5692  :  abc12345678?
# 5693  :  abc12345678,
# 5694  :  abc12345678/
# 5695  :  abc12345678!!
# 5696  :  abc12345678.:
# 5697  :  abc12345678&#
# 5698  :  abc12345678**
# 5699  :  abc12345678…
# 5700  :  abc12345678:
# 5701  :  abc12345678$$
# 5702  :  abc12345678__
# 5703  :  asd123456.
# 5704  :  asd123456_
# 5705  :  asd123456!
# 5706  :  asd123456@
# 5707  :  asd123456-
# 5708  :  asd123456:
# 5709  :  asd123456#
# 5710  :  asd123456*
# 5711  :  asd123456$
# 5712  :  asd123456
# 5713  :  asd123456&
# 5714  :  asd123456+
# 5715  :  asd123456?
# 5716  :  asd123456,
# 5717  :  asd123456/
# 5718  :  asd123456!!
# 5719  :  asd123456.:
# 5720  :  asd123456&#
# 5721  :  asd123456**
# 5722  :  asd123456…
# 5723  :  asd123456:
# 5724  :  asd123456$$
# 5725  :  asd123456__
# 5726  :  asd123!!
# 5727  :  asd123.:
# 5728  :  asd123&#
# 5729  :  asd123**
# 5730  :  asd123$$
# 5731  :  asd123__
# 5732  :  asd123456789.
# 5733  :  asd123456789_
# 5734  :  asd123456789!
# 5735  :  asd123456789@
# 5736  :  asd123456789-
# 5737  :  asd123456789:
# 5738  :  asd123456789#
# 5739  :  asd123456789*
# 5740  :  asd123456789$
# 5741  :  asd123456789
# 5742  :  asd123456789&
# 5743  :  asd123456789+
# 5744  :  asd123456789?
# 5745  :  asd123456789,
# 5746  :  asd123456789/
# 5747  :  asd123456789!!
# 5748  :  asd123456789.:
# 5749  :  asd123456789&#
# 5750  :  asd123456789**
# 5751  :  asd123456789…
# 5752  :  asd123456789:
# 5753  :  asd123456789$$
# 5754  :  asd123456789__
# 5755  :  asd12345.
# 5756  :  asd12345_
# 5757  :  asd12345!
# 5758  :  asd12345@
# 5759  :  asd12345-
# 5760  :  asd12345:
# 5761  :  asd12345#
# 5762  :  asd12345*
# 5763  :  asd12345$
# 5764  :  asd12345
# 5765  :  asd12345&
# 5766  :  asd12345+
# 5767  :  asd12345?
# 5768  :  asd12345,
# 5769  :  asd12345/
# 5770  :  asd12345!!
# 5771  :  asd12345.:
# 5772  :  asd12345&#
# 5773  :  asd12345**
# 5774  :  asd12345…
# 5775  :  asd12345:
# 5776  :  asd12345$$
# 5777  :  asd12345__
# 5778  :  asd1234.
# 5779  :  asd1234_
# 5780  :  asd1234!
# 5781  :  asd1234@
# 5782  :  asd1234-
# 5783  :  asd1234:
# 5784  :  asd1234#
# 5785  :  asd1234*
# 5786  :  asd1234$
# 5787  :  asd1234
# 5788  :  asd1234&
# 5789  :  asd1234+
# 5790  :  asd1234?
# 5791  :  asd1234,
# 5792  :  asd1234/
# 5793  :  asd1234!!
# 5794  :  asd1234.:
# 5795  :  asd1234&#
# 5796  :  asd1234**
# 5797  :  asd1234…
# 5798  :  asd1234:
# 5799  :  asd1234$$
# 5800  :  asd1234__
# 5801  :  asd12345678.
# 5802  :  asd12345678_
# 5803  :  asd12345678!
# 5804  :  asd12345678@
# 5805  :  asd12345678-
# 5806  :  asd12345678:
# 5807  :  asd12345678#
# 5808  :  asd12345678*
# 5809  :  asd12345678$
# 5810  :  asd12345678
# 5811  :  asd12345678&
# 5812  :  asd12345678+
# 5813  :  asd12345678?
# 5814  :  asd12345678,
# 5815  :  asd12345678/
# 5816  :  asd12345678!!
# 5817  :  asd12345678.:
# 5818  :  asd12345678&#
# 5819  :  asd12345678**
# 5820  :  asd12345678…
# 5821  :  asd12345678:
# 5822  :  asd12345678$$
# 5823  :  asd12345678__
# 5824  :  to123456.
# 5825  :  to123456_
# 5826  :  to123456!
# 5827  :  to123456@
# 5828  :  to123456-
# 5829  :  to123456:
# 5830  :  to123456#
# 5831  :  to123456*
# 5832  :  to123456$
# 5833  :  to123456
# 5834  :  to123456&
# 5835  :  to123456+
# 5836  :  to123456?
# 5837  :  to123456,
# 5838  :  to123456/
# 5839  :  to123456!!
# 5840  :  to123456.:
# 5841  :  to123456&#
# 5842  :  to123456**
# 5843  :  to123456…
# 5844  :  to123456:
# 5845  :  to123456$$
# 5846  :  to123456__
# 5847  :  to123456789.
# 5848  :  to123456789_
# 5849  :  to123456789!
# 5850  :  to123456789@
# 5851  :  to123456789-
# 5852  :  to123456789:
# 5853  :  to123456789#
# 5854  :  to123456789*
# 5855  :  to123456789$
# 5856  :  to123456789
# 5857  :  to123456789&
# 5858  :  to123456789+
# 5859  :  to123456789?
# 5860  :  to123456789,
# 5861  :  to123456789/
# 5862  :  to123456789!!
# 5863  :  to123456789.:
# 5864  :  to123456789&#
# 5865  :  to123456789**
# 5866  :  to123456789…
# 5867  :  to123456789:
# 5868  :  to123456789$$
# 5869  :  to123456789__
# 5870  :  to12345.
# 5871  :  to12345_
# 5872  :  to12345!
# 5873  :  to12345@
# 5874  :  to12345-
# 5875  :  to12345:
# 5876  :  to12345#
# 5877  :  to12345*
# 5878  :  to12345$
# 5879  :  to12345
# 5880  :  to12345&
# 5881  :  to12345+
# 5882  :  to12345?
# 5883  :  to12345,
# 5884  :  to12345/
# 5885  :  to12345!!
# 5886  :  to12345.:
# 5887  :  to12345&#
# 5888  :  to12345**
# 5889  :  to12345…
# 5890  :  to12345:
# 5891  :  to12345$$
# 5892  :  to12345__
# 5893  :  to1234!!
# 5894  :  to1234.:
# 5895  :  to1234&#
# 5896  :  to1234**
# 5897  :  to1234$$
# 5898  :  to1234__
# 5899  :  to12345678.
# 5900  :  to12345678_
# 5901  :  to12345678!
# 5902  :  to12345678@
# 5903  :  to12345678-
# 5904  :  to12345678:
# 5905  :  to12345678#
# 5906  :  to12345678*
# 5907  :  to12345678$
# 5908  :  to12345678
# 5909  :  to12345678&
# 5910  :  to12345678+
# 5911  :  to12345678?
# 5912  :  to12345678,
# 5913  :  to12345678/
# 5914  :  to12345678!!
# 5915  :  to12345678.:
# 5916  :  to12345678&#
# 5917  :  to12345678**
# 5918  :  to12345678…
# 5919  :  to12345678:
# 5920  :  to12345678$$
# 5921  :  to12345678__
# 5922  :  in123456.
# 5923  :  in123456_
# 5924  :  in123456!
# 5925  :  in123456@
# 5926  :  in123456-
# 5927  :  in123456:
# 5928  :  in123456#
# 5929  :  in123456*
# 5930  :  in123456$
# 5931  :  in123456
# 5932  :  in123456&
# 5933  :  in123456+
# 5934  :  in123456?
# 5935  :  in123456,
# 5936  :  in123456/
# 5937  :  in123456!!
# 5938  :  in123456.:
# 5939  :  in123456&#
# 5940  :  in123456**
# 5941  :  in123456…
# 5942  :  in123456:
# 5943  :  in123456$$
# 5944  :  in123456__
# 5945  :  in123456789.
# 5946  :  in123456789_
# 5947  :  in123456789!
# 5948  :  in123456789@
# 5949  :  in123456789-
# 5950  :  in123456789:
# 5951  :  in123456789#
# 5952  :  in123456789*
# 5953  :  in123456789$
# 5954  :  in123456789
# 5955  :  in123456789&
# 5956  :  in123456789+
# 5957  :  in123456789?
# 5958  :  in123456789,
# 5959  :  in123456789/
# 5960  :  in123456789!!
# 5961  :  in123456789.:
# 5962  :  in123456789&#
# 5963  :  in123456789**
# 5964  :  in123456789…
# 5965  :  in123456789:
# 5966  :  in123456789$$
# 5967  :  in123456789__
# 5968  :  in12345.
# 5969  :  in12345_
# 5970  :  in12345!
# 5971  :  in12345@
# 5972  :  in12345-
# 5973  :  in12345:
# 5974  :  in12345#
# 5975  :  in12345*
# 5976  :  in12345$
# 5977  :  in12345
# 5978  :  in12345&
# 5979  :  in12345+
# 5980  :  in12345?
# 5981  :  in12345,
# 5982  :  in12345/
# 5983  :  in12345!!
# 5984  :  in12345.:
# 5985  :  in12345&#
# 5986  :  in12345**
# 5987  :  in12345…
# 5988  :  in12345:
# 5989  :  in12345$$
# 5990  :  in12345__
# 5991  :  in1234!!
# 5992  :  in1234.:
# 5993  :  in1234&#
# 5994  :  in1234**
# 5995  :  in1234$$
# 5996  :  in1234__
# 5997  :  in12345678.
# 5998  :  in12345678_
# 5999  :  in12345678!
# 6000  :  in12345678@
# 6001  :  in12345678-
# 6002  :  in12345678:
# 6003  :  in12345678#
# 6004  :  in12345678*
# 6005  :  in12345678$
# 6006  :  in12345678
# 6007  :  in12345678&
# 6008  :  in12345678+
# 6009  :  in12345678?
# 6010  :  in12345678,
# 6011  :  in12345678/
# 6012  :  in12345678!!
# 6013  :  in12345678.:
# 6014  :  in12345678&#
# 6015  :  in12345678**
# 6016  :  in12345678…
# 6017  :  in12345678:
# 6018  :  in12345678$$
# 6019  :  in12345678__

# %%
# Generate using ONLY personal

# create personal dicos

#Create dictionaries
personal_string_dict = {
    'Name': list(set(filtered_ner_neutral.get('PERSON', [])).union(filtered_df_words.get('PERSON', []))),
    'City': list(set(filtered_ner_neutral.get('GPE', [])).union(filtered_df_words.get('GPE', [])))
    + list(set(filtered_ner_neutral.get('LOC', [])).union(filtered_df_words.get('LOC', []))),
}

personal_digit_dict = {
    'Number': list(set(filtered_ner_neutral.get('CARDINAL', [])).union(filtered_df_words.get('CARDINAL', [])))
    + [str(i) for i in range(10)],
    'Year': [date[-4:] for date in list(set(filtered_ner_neutral.get('DATE', [])).union(filtered_df_words.get('DATE', []))) if date[-4:].isdigit()],
}

personal_special_dict = {
    'Simple': ['.', '_', '!', '@', '-', ':', '#', '*', '$', ' ', '&', '+', '?', ',', '/'],
    'Combined': ['!!', '.:', '&#', '**', '…', ':', '$$', '__'],
}

# Create lists for each dictionary
personal_string_list = list(itertools.chain.from_iterable(personal_string_dict.values()))
personal_digit_list = list(itertools.chain.from_iterable(personal_digit_dict.values()))
personal_special_list = list(itertools.chain.from_iterable(personal_special_dict.values()))


# combine
personal_password_combinations = generate_passwords(personal_string_list, personal_digit_list, personal_special_list)

print("Generated PERSONAL Password Combinations:")
i = 0
for password in personal_password_combinations:
    print(i , ' : ' , password)
    i+=1
# Out:
# Generated PERSONAL Password Combinations:
# 0  :  georges.0
# 1  :  georges.1
# 2  :  georges.2
# 3  :  georges.3
# 4  :  georges.4
# 5  :  georges.5
# 6  :  georges.6
# 7  :  georges.7
# 8  :  georges.8
# 9  :  georges.9
# 10  :  georges_0
# 11  :  georges_1
# 12  :  georges_2
# 13  :  georges_3
# 14  :  georges_4
# 15  :  georges_5
# 16  :  georges_6
# 17  :  georges_7
# 18  :  georges_8
# 19  :  georges_9
# 20  :  georges!0
# 21  :  georges!1
# 22  :  georges!2
# 23  :  georges!3
# 24  :  georges!4
# 25  :  georges!5
# 26  :  georges!6
# 27  :  georges!7
# 28  :  georges!8
# 29  :  georges!9
# 30  :  georges@0
# 31  :  georges@1
# 32  :  georges@2
# 33  :  georges@3
# 34  :  georges@4
# 35  :  georges@5
# 36  :  georges@6
# 37  :  georges@7
# 38  :  georges@8
# 39  :  georges@9
# 40  :  georges-0
# 41  :  georges-1
# 42  :  georges-2
# 43  :  georges-3
# 44  :  georges-4
# 45  :  georges-5
# 46  :  georges-6
# 47  :  georges-7
# 48  :  georges-8
# 49  :  georges-9
# 50  :  georges:0
# 51  :  georges:1
# 52  :  georges:2
# 53  :  georges:3
# 54  :  georges:4
# 55  :  georges:5
# 56  :  georges:6
# 57  :  georges:7
# 58  :  georges:8
# 59  :  georges:9
# 60  :  georges#0
# 61  :  georges#1
# 62  :  georges#2
# 63  :  georges#3
# 64  :  georges#4
# 65  :  georges#5
# 66  :  georges#6
# 67  :  georges#7
# 68  :  georges#8
# 69  :  georges#9
# 70  :  georges*0
# 71  :  georges*1
# 72  :  georges*2
# 73  :  georges*3
# 74  :  georges*4
# 75  :  georges*5
# 76  :  georges*6
# 77  :  georges*7
# 78  :  georges*8
# 79  :  georges*9
# 80  :  georges$0
# 81  :  georges$1
# 82  :  georges$2
# 83  :  georges$3
# 84  :  georges$4
# 85  :  georges$5
# 86  :  georges$6
# 87  :  georges$7
# 88  :  georges$8
# 89  :  georges$9
# 90  :  georges 0
# 91  :  georges 1
# 92  :  georges 2
# 93  :  georges 3
# 94  :  georges 4
# 95  :  georges 5
# 96  :  georges 6
# 97  :  georges 7
# 98  :  georges 8
# 99  :  georges 9
# 100  :  georges&0
# 101  :  georges&1
# 102  :  georges&2
# 103  :  georges&3
# 104  :  georges&4
# 105  :  georges&5
# 106  :  georges&6
# 107  :  georges&7
# 108  :  georges&8
# 109  :  georges&9
# 110  :  georges+0
# 111  :  georges+1
# 112  :  georges+2
# 113  :  georges+3
# 114  :  georges+4
# 115  :  georges+5
# 116  :  georges+6
# 117  :  georges+7
# 118  :  georges+8
# 119  :  georges+9
# 120  :  georges?0
# 121  :  georges?1
# 122  :  georges?2
# 123  :  georges?3
# 124  :  georges?4
# 125  :  georges?5
# 126  :  georges?6
# 127  :  georges?7
# 128  :  georges?8
# 129  :  georges?9
# 130  :  georges,0
# 131  :  georges,1
# 132  :  georges,2
# 133  :  georges,3
# 134  :  georges,4
# 135  :  georges,5
# 136  :  georges,6
# 137  :  georges,7
# 138  :  georges,8
# 139  :  georges,9
# 140  :  georges/0
# 141  :  georges/1
# 142  :  georges/2
# 143  :  georges/3
# 144  :  georges/4
# 145  :  georges/5
# 146  :  georges/6
# 147  :  georges/7
# 148  :  georges/8
# 149  :  georges/9
# 150  :  georges!!0
# 151  :  georges!!1
# 152  :  georges!!2
# 153  :  georges!!3
# 154  :  georges!!4
# 155  :  georges!!5
# 156  :  georges!!6
# 157  :  georges!!7
# 158  :  georges!!8
# 159  :  georges!!9
# 160  :  georges.:0
# 161  :  georges.:1
# 162  :  georges.:2
# 163  :  georges.:3
# 164  :  georges.:4
# 165  :  georges.:5
# 166  :  georges.:6
# 167  :  georges.:7
# 168  :  georges.:8
# 169  :  georges.:9
# 170  :  georges&#0
# 171  :  georges&#1
# 172  :  georges&#2
# 173  :  georges&#3
# 174  :  georges&#4
# 175  :  georges&#5
# 176  :  georges&#6
# 177  :  georges&#7
# 178  :  georges&#8
# 179  :  georges&#9
# 180  :  georges**0
# 181  :  georges**1
# 182  :  georges**2
# 183  :  georges**3
# 184  :  georges**4
# 185  :  georges**5
# 186  :  georges**6
# 187  :  georges**7
# 188  :  georges**8
# 189  :  georges**9
# 190  :  georges…0
# 191  :  georges…1
# 192  :  georges…2
# 193  :  georges…3
# 194  :  georges…4
# 195  :  georges…5
# 196  :  georges…6
# 197  :  georges…7
# 198  :  georges…8
# 199  :  georges…9
# 200  :  georges:0
# 201  :  georges:1
# 202  :  georges:2
# 203  :  georges:3
# 204  :  georges:4
# 205  :  georges:5
# 206  :  georges:6
# 207  :  georges:7
# 208  :  georges:8
# 209  :  georges:9
# 210  :  georges$$0
# 211  :  georges$$1
# 212  :  georges$$2
# 213  :  georges$$3
# 214  :  georges$$4
# 215  :  georges$$5
# 216  :  georges$$6
# 217  :  georges$$7
# 218  :  georges$$8
# 219  :  georges$$9
# 220  :  georges__0
# 221  :  georges__1
# 222  :  georges__2
# 223  :  georges__3
# 224  :  georges__4
# 225  :  georges__5
# 226  :  georges__6
# 227  :  georges__7
# 228  :  georges__8
# 229  :  georges__9
# 230  :  harrys.0
# 231  :  harrys.1
# 232  :  harrys.2
# 233  :  harrys.3
# 234  :  harrys.4
# 235  :  harrys.5
# 236  :  harrys.6
# 237  :  harrys.7
# 238  :  harrys.8
# 239  :  harrys.9
# 240  :  harrys_0
# 241  :  harrys_1
# 242  :  harrys_2
# 243  :  harrys_3
# 244  :  harrys_4
# 245  :  harrys_5
# 246  :  harrys_6
# 247  :  harrys_7
# 248  :  harrys_8
# 249  :  harrys_9
# 250  :  harrys!0
# 251  :  harrys!1
# 252  :  harrys!2
# 253  :  harrys!3
# 254  :  harrys!4
# 255  :  harrys!5
# 256  :  harrys!6
# 257  :  harrys!7
# 258  :  harrys!8
# 259  :  harrys!9
# 260  :  harrys@0
# 261  :  harrys@1
# 262  :  harrys@2
# 263  :  harrys@3
# 264  :  harrys@4
# 265  :  harrys@5
# 266  :  harrys@6
# 267  :  harrys@7
# 268  :  harrys@8
# 269  :  harrys@9
# 270  :  harrys-0
# 271  :  harrys-1
# 272  :  harrys-2
# 273  :  harrys-3
# 274  :  harrys-4
# 275  :  harrys-5
# 276  :  harrys-6
# 277  :  harrys-7
# 278  :  harrys-8
# 279  :  harrys-9
# 280  :  harrys:0
# 281  :  harrys:1
# 282  :  harrys:2
# 283  :  harrys:3
# 284  :  harrys:4
# 285  :  harrys:5
# 286  :  harrys:6
# 287  :  harrys:7
# 288  :  harrys:8
# 289  :  harrys:9
# 290  :  harrys#0
# 291  :  harrys#1
# 292  :  harrys#2
# 293  :  harrys#3
# 294  :  harrys#4
# 295  :  harrys#5
# 296  :  harrys#6
# 297  :  harrys#7
# 298  :  harrys#8
# 299  :  harrys#9
# 300  :  harrys*0
# 301  :  harrys*1
# 302  :  harrys*2
# 303  :  harrys*3
# 304  :  harrys*4
# 305  :  harrys*5
# 306  :  harrys*6
# 307  :  harrys*7
# 308  :  harrys*8
# 309  :  harrys*9
# 310  :  harrys$0
# 311  :  harrys$1
# 312  :  harrys$2
# 313  :  harrys$3
# 314  :  harrys$4
# 315  :  harrys$5
# 316  :  harrys$6
# 317  :  harrys$7
# 318  :  harrys$8
# 319  :  harrys$9
# 320  :  harrys 0
# 321  :  harrys 1
# 322  :  harrys 2
# 323  :  harrys 3
# 324  :  harrys 4
# 325  :  harrys 5
# 326  :  harrys 6
# 327  :  harrys 7
# 328  :  harrys 8
# 329  :  harrys 9
# 330  :  harrys&0
# 331  :  harrys&1
# 332  :  harrys&2
# 333  :  harrys&3
# 334  :  harrys&4
# 335  :  harrys&5
# 336  :  harrys&6
# 337  :  harrys&7
# 338  :  harrys&8
# 339  :  harrys&9
# 340  :  harrys+0
# 341  :  harrys+1
# 342  :  harrys+2
# 343  :  harrys+3
# 344  :  harrys+4
# 345  :  harrys+5
# 346  :  harrys+6
# 347  :  harrys+7
# 348  :  harrys+8
# 349  :  harrys+9
# 350  :  harrys?0
# 351  :  harrys?1
# 352  :  harrys?2
# 353  :  harrys?3
# 354  :  harrys?4
# 355  :  harrys?5
# 356  :  harrys?6
# 357  :  harrys?7
# 358  :  harrys?8
# 359  :  harrys?9
# 360  :  harrys,0
# 361  :  harrys,1
# 362  :  harrys,2
# 363  :  harrys,3
# 364  :  harrys,4
# 365  :  harrys,5
# 366  :  harrys,6
# 367  :  harrys,7
# 368  :  harrys,8
# 369  :  harrys,9
# 370  :  harrys/0
# 371  :  harrys/1
# 372  :  harrys/2
# 373  :  harrys/3
# 374  :  harrys/4
# 375  :  harrys/5
# 376  :  harrys/6
# 377  :  harrys/7
# 378  :  harrys/8
# 379  :  harrys/9
# 380  :  harrys!!0
# 381  :  harrys!!1
# 382  :  harrys!!2
# 383  :  harrys!!3
# 384  :  harrys!!4
# 385  :  harrys!!5
# 386  :  harrys!!6
# 387  :  harrys!!7
# 388  :  harrys!!8
# 389  :  harrys!!9
# 390  :  harrys.:0
# 391  :  harrys.:1
# 392  :  harrys.:2
# 393  :  harrys.:3
# 394  :  harrys.:4
# 395  :  harrys.:5
# 396  :  harrys.:6
# 397  :  harrys.:7
# 398  :  harrys.:8
# 399  :  harrys.:9
# 400  :  harrys&#0
# 401  :  harrys&#1
# 402  :  harrys&#2
# 403  :  harrys&#3
# 404  :  harrys&#4
# 405  :  harrys&#5
# 406  :  harrys&#6
# 407  :  harrys&#7
# 408  :  harrys&#8
# 409  :  harrys&#9
# 410  :  harrys**0
# 411  :  harrys**1
# 412  :  harrys**2
# 413  :  harrys**3
# 414  :  harrys**4
# 415  :  harrys**5
# 416  :  harrys**6
# 417  :  harrys**7
# 418  :  harrys**8
# 419  :  harrys**9
# 420  :  harrys…0
# 421  :  harrys…1
# 422  :  harrys…2
# 423  :  harrys…3
# 424  :  harrys…4
# 425  :  harrys…5
# 426  :  harrys…6
# 427  :  harrys…7
# 428  :  harrys…8
# 429  :  harrys…9
# 430  :  harrys:0
# 431  :  harrys:1
# 432  :  harrys:2
# 433  :  harrys:3
# 434  :  harrys:4
# 435  :  harrys:5
# 436  :  harrys:6
# 437  :  harrys:7
# 438  :  harrys:8
# 439  :  harrys:9
# 440  :  harrys$$0
# 441  :  harrys$$1
# 442  :  harrys$$2
# 443  :  harrys$$3
# 444  :  harrys$$4
# 445  :  harrys$$5
# 446  :  harrys$$6
# 447  :  harrys$$7
# 448  :  harrys$$8
# 449  :  harrys$$9
# 450  :  harrys__0
# 451  :  harrys__1
# 452  :  harrys__2
# 453  :  harrys__3
# 454  :  harrys__4
# 455  :  harrys__5
# 456  :  harrys__6
# 457  :  harrys__7
# 458  :  harrys__8
# 459  :  harrys__9
# 460  :  toulouse.0
# 461  :  toulouse.1
# 462  :  toulouse.2
# 463  :  toulouse.3
# 464  :  toulouse.4
# 465  :  toulouse.5
# 466  :  toulouse.6
# 467  :  toulouse.7
# 468  :  toulouse.8
# 469  :  toulouse.9
# 470  :  toulouse_0
# 471  :  toulouse_1
# 472  :  toulouse_2
# 473  :  toulouse_3
# 474  :  toulouse_4
# 475  :  toulouse_5
# 476  :  toulouse_6
# 477  :  toulouse_7
# 478  :  toulouse_8
# 479  :  toulouse_9
# 480  :  toulouse!0
# 481  :  toulouse!1
# 482  :  toulouse!2
# 483  :  toulouse!3
# 484  :  toulouse!4
# 485  :  toulouse!5
# 486  :  toulouse!6
# 487  :  toulouse!7
# 488  :  toulouse!8
# 489  :  toulouse!9
# 490  :  toulouse@0
# 491  :  toulouse@1
# 492  :  toulouse@2
# 493  :  toulouse@3
# 494  :  toulouse@4
# 495  :  toulouse@5
# 496  :  toulouse@6
# 497  :  toulouse@7
# 498  :  toulouse@8
# 499  :  toulouse@9
# 500  :  toulouse-0
# 501  :  toulouse-1
# 502  :  toulouse-2
# 503  :  toulouse-3
# 504  :  toulouse-4
# 505  :  toulouse-5
# 506  :  toulouse-6
# 507  :  toulouse-7
# 508  :  toulouse-8
# 509  :  toulouse-9
# 510  :  toulouse:0
# 511  :  toulouse:1
# 512  :  toulouse:2
# 513  :  toulouse:3
# 514  :  toulouse:4
# 515  :  toulouse:5
# 516  :  toulouse:6
# 517  :  toulouse:7
# 518  :  toulouse:8
# 519  :  toulouse:9
# 520  :  toulouse#0
# 521  :  toulouse#1
# 522  :  toulouse#2
# 523  :  toulouse#3
# 524  :  toulouse#4
# 525  :  toulouse#5
# 526  :  toulouse#6
# 527  :  toulouse#7
# 528  :  toulouse#8
# 529  :  toulouse#9
# 530  :  toulouse*0
# 531  :  toulouse*1
# 532  :  toulouse*2
# 533  :  toulouse*3
# 534  :  toulouse*4
# 535  :  toulouse*5
# 536  :  toulouse*6
# 537  :  toulouse*7
# 538  :  toulouse*8
# 539  :  toulouse*9
# 540  :  toulouse$0
# 541  :  toulouse$1
# 542  :  toulouse$2
# 543  :  toulouse$3
# 544  :  toulouse$4
# 545  :  toulouse$5
# 546  :  toulouse$6
# 547  :  toulouse$7
# 548  :  toulouse$8
# 549  :  toulouse$9
# 550  :  toulouse 0
# 551  :  toulouse 1
# 552  :  toulouse 2
# 553  :  toulouse 3
# 554  :  toulouse 4
# 555  :  toulouse 5
# 556  :  toulouse 6
# 557  :  toulouse 7
# 558  :  toulouse 8
# 559  :  toulouse 9
# 560  :  toulouse&0
# 561  :  toulouse&1
# 562  :  toulouse&2
# 563  :  toulouse&3
# 564  :  toulouse&4
# 565  :  toulouse&5
# 566  :  toulouse&6
# 567  :  toulouse&7
# 568  :  toulouse&8
# 569  :  toulouse&9
# 570  :  toulouse+0
# 571  :  toulouse+1
# 572  :  toulouse+2
# 573  :  toulouse+3
# 574  :  toulouse+4
# 575  :  toulouse+5
# 576  :  toulouse+6
# 577  :  toulouse+7
# 578  :  toulouse+8
# 579  :  toulouse+9
# 580  :  toulouse?0
# 581  :  toulouse?1
# 582  :  toulouse?2
# 583  :  toulouse?3
# 584  :  toulouse?4
# 585  :  toulouse?5
# 586  :  toulouse?6
# 587  :  toulouse?7
# 588  :  toulouse?8
# 589  :  toulouse?9
# 590  :  toulouse,0
# 591  :  toulouse,1
# 592  :  toulouse,2
# 593  :  toulouse,3
# 594  :  toulouse,4
# 595  :  toulouse,5
# 596  :  toulouse,6
# 597  :  toulouse,7
# 598  :  toulouse,8
# 599  :  toulouse,9
# 600  :  toulouse/0
# 601  :  toulouse/1
# 602  :  toulouse/2
# 603  :  toulouse/3
# 604  :  toulouse/4
# 605  :  toulouse/5
# 606  :  toulouse/6
# 607  :  toulouse/7
# 608  :  toulouse/8
# 609  :  toulouse/9
# 610  :  toulouse!!0
# 611  :  toulouse!!1
# 612  :  toulouse!!2
# 613  :  toulouse!!3
# 614  :  toulouse!!4
# 615  :  toulouse!!5
# 616  :  toulouse!!6
# 617  :  toulouse!!7
# 618  :  toulouse!!8
# 619  :  toulouse!!9
# 620  :  toulouse.:0
# 621  :  toulouse.:1
# 622  :  toulouse.:2
# 623  :  toulouse.:3
# 624  :  toulouse.:4
# 625  :  toulouse.:5
# 626  :  toulouse.:6
# 627  :  toulouse.:7
# 628  :  toulouse.:8
# 629  :  toulouse.:9
# 630  :  toulouse&#0
# 631  :  toulouse&#1
# 632  :  toulouse&#2
# 633  :  toulouse&#3
# 634  :  toulouse&#4
# 635  :  toulouse&#5
# 636  :  toulouse&#6
# 637  :  toulouse&#7
# 638  :  toulouse&#8
# 639  :  toulouse&#9
# 640  :  toulouse**0
# 641  :  toulouse**1
# 642  :  toulouse**2
# 643  :  toulouse**3
# 644  :  toulouse**4
# 645  :  toulouse**5
# 646  :  toulouse**6
# 647  :  toulouse**7
# 648  :  toulouse**8
# 649  :  toulouse**9
# 650  :  toulouse…0
# 651  :  toulouse…1
# 652  :  toulouse…2
# 653  :  toulouse…3
# 654  :  toulouse…4
# 655  :  toulouse…5
# 656  :  toulouse…6
# 657  :  toulouse…7
# 658  :  toulouse…8
# 659  :  toulouse…9
# 660  :  toulouse:0
# 661  :  toulouse:1
# 662  :  toulouse:2
# 663  :  toulouse:3
# 664  :  toulouse:4
# 665  :  toulouse:5
# 666  :  toulouse:6
# 667  :  toulouse:7
# 668  :  toulouse:8
# 669  :  toulouse:9
# 670  :  toulouse$$0
# 671  :  toulouse$$1
# 672  :  toulouse$$2
# 673  :  toulouse$$3
# 674  :  toulouse$$4
# 675  :  toulouse$$5
# 676  :  toulouse$$6
# 677  :  toulouse$$7
# 678  :  toulouse$$8
# 679  :  toulouse$$9
# 680  :  toulouse__0
# 681  :  toulouse__1
# 682  :  toulouse__2
# 683  :  toulouse__3
# 684  :  toulouse__4
# 685  :  toulouse__5
# 686  :  toulouse__6
# 687  :  toulouse__7
# 688  :  toulouse__8
# 689  :  toulouse__9
# 690  :  georges0.
# 691  :  georges0_
# 692  :  georges0!
# 693  :  georges0@
# 694  :  georges0-
# 695  :  georges0:
# 696  :  georges0#
# 697  :  georges0*
# 698  :  georges0$
# 699  :  georges0
# 700  :  georges0&
# 701  :  georges0+
# 702  :  georges0?
# 703  :  georges0,
# 704  :  georges0/
# 705  :  georges0!!
# 706  :  georges0.:
# 707  :  georges0&#
# 708  :  georges0**
# 709  :  georges0…
# 710  :  georges0:
# 711  :  georges0$$
# 712  :  georges0__
# 713  :  georges1.
# 714  :  georges1_
# 715  :  georges1!
# 716  :  georges1@
# 717  :  georges1-
# 718  :  georges1:
# 719  :  georges1#
# 720  :  georges1*
# 721  :  georges1$
# 722  :  georges1
# 723  :  georges1&
# 724  :  georges1+
# 725  :  georges1?
# 726  :  georges1,
# 727  :  georges1/
# 728  :  georges1!!
# 729  :  georges1.:
# 730  :  georges1&#
# 731  :  georges1**
# 732  :  georges1…
# 733  :  georges1:
# 734  :  georges1$$
# 735  :  georges1__
# 736  :  georges2.
# 737  :  georges2_
# 738  :  georges2!
# 739  :  georges2@
# 740  :  georges2-
# 741  :  georges2:
# 742  :  georges2#
# 743  :  georges2*
# 744  :  georges2$
# 745  :  georges2
# 746  :  georges2&
# 747  :  georges2+
# 748  :  georges2?
# 749  :  georges2,
# 750  :  georges2/
# 751  :  georges2!!
# 752  :  georges2.:
# 753  :  georges2&#
# 754  :  georges2**
# 755  :  georges2…
# 756  :  georges2:
# 757  :  georges2$$
# 758  :  georges2__
# 759  :  georges3.
# 760  :  georges3_
# 761  :  georges3!
# 762  :  georges3@
# 763  :  georges3-
# 764  :  georges3:
# 765  :  georges3#
# 766  :  georges3*
# 767  :  georges3$
# 768  :  georges3
# 769  :  georges3&
# 770  :  georges3+
# 771  :  georges3?
# 772  :  georges3,
# 773  :  georges3/
# 774  :  georges3!!
# 775  :  georges3.:
# 776  :  georges3&#
# 777  :  georges3**
# 778  :  georges3…
# 779  :  georges3:
# 780  :  georges3$$
# 781  :  georges3__
# 782  :  georges4.
# 783  :  georges4_
# 784  :  georges4!
# 785  :  georges4@
# 786  :  georges4-
# 787  :  georges4:
# 788  :  georges4#
# 789  :  georges4*
# 790  :  georges4$
# 791  :  georges4
# 792  :  georges4&
# 793  :  georges4+
# 794  :  georges4?
# 795  :  georges4,
# 796  :  georges4/
# 797  :  georges4!!
# 798  :  georges4.:
# 799  :  georges4&#
# 800  :  georges4**
# 801  :  georges4…
# 802  :  georges4:
# 803  :  georges4$$
# 804  :  georges4__
# 805  :  georges5.
# 806  :  georges5_
# 807  :  georges5!
# 808  :  georges5@
# 809  :  georges5-
# 810  :  georges5:
# 811  :  georges5#
# 812  :  georges5*
# 813  :  georges5$
# 814  :  georges5
# 815  :  georges5&
# 816  :  georges5+
# 817  :  georges5?
# 818  :  georges5,
# 819  :  georges5/
# 820  :  georges5!!
# 821  :  georges5.:
# 822  :  georges5&#
# 823  :  georges5**
# 824  :  georges5…
# 825  :  georges5:
# 826  :  georges5$$
# 827  :  georges5__
# 828  :  georges6.
# 829  :  georges6_
# 830  :  georges6!
# 831  :  georges6@
# 832  :  georges6-
# 833  :  georges6:
# 834  :  georges6#
# 835  :  georges6*
# 836  :  georges6$
# 837  :  georges6
# 838  :  georges6&
# 839  :  georges6+
# 840  :  georges6?
# 841  :  georges6,
# 842  :  georges6/
# 843  :  georges6!!
# 844  :  georges6.:
# 845  :  georges6&#
# 846  :  georges6**
# 847  :  georges6…
# 848  :  georges6:
# 849  :  georges6$$
# 850  :  georges6__
# 851  :  georges7.
# 852  :  georges7_
# 853  :  georges7!
# 854  :  georges7@
# 855  :  georges7-
# 856  :  georges7:
# 857  :  georges7#
# 858  :  georges7*
# 859  :  georges7$
# 860  :  georges7
# 861  :  georges7&
# 862  :  georges7+
# 863  :  georges7?
# 864  :  georges7,
# 865  :  georges7/
# 866  :  georges7!!
# 867  :  georges7.:
# 868  :  georges7&#
# 869  :  georges7**
# 870  :  georges7…
# 871  :  georges7:
# 872  :  georges7$$
# 873  :  georges7__
# 874  :  georges8.
# 875  :  georges8_
# 876  :  georges8!
# 877  :  georges8@
# 878  :  georges8-
# 879  :  georges8:
# 880  :  georges8#
# 881  :  georges8*
# 882  :  georges8$
# 883  :  georges8
# 884  :  georges8&
# 885  :  georges8+
# 886  :  georges8?
# 887  :  georges8,
# 888  :  georges8/
# 889  :  georges8!!
# 890  :  georges8.:
# 891  :  georges8&#
# 892  :  georges8**
# 893  :  georges8…
# 894  :  georges8:
# 895  :  georges8$$
# 896  :  georges8__
# 897  :  georges9.
# 898  :  georges9_
# 899  :  georges9!
# 900  :  georges9@
# 901  :  georges9-
# 902  :  georges9:
# 903  :  georges9#
# 904  :  georges9*
# 905  :  georges9$
# 906  :  georges9
# 907  :  georges9&
# 908  :  georges9+
# 909  :  georges9?
# 910  :  georges9,
# 911  :  georges9/
# 912  :  georges9!!
# 913  :  georges9.:
# 914  :  georges9&#
# 915  :  georges9**
# 916  :  georges9…
# 917  :  georges9:
# 918  :  georges9$$
# 919  :  georges9__
# 920  :  harrys0.
# 921  :  harrys0_
# 922  :  harrys0!
# 923  :  harrys0@
# 924  :  harrys0-
# 925  :  harrys0:
# 926  :  harrys0#
# 927  :  harrys0*
# 928  :  harrys0$
# 929  :  harrys0
# 930  :  harrys0&
# 931  :  harrys0+
# 932  :  harrys0?
# 933  :  harrys0,
# 934  :  harrys0/
# 935  :  harrys0!!
# 936  :  harrys0.:
# 937  :  harrys0&#
# 938  :  harrys0**
# 939  :  harrys0…
# 940  :  harrys0:
# 941  :  harrys0$$
# 942  :  harrys0__
# 943  :  harrys1.
# 944  :  harrys1_
# 945  :  harrys1!
# 946  :  harrys1@
# 947  :  harrys1-
# 948  :  harrys1:
# 949  :  harrys1#
# 950  :  harrys1*
# 951  :  harrys1$
# 952  :  harrys1
# 953  :  harrys1&
# 954  :  harrys1+
# 955  :  harrys1?
# 956  :  harrys1,
# 957  :  harrys1/
# 958  :  harrys1!!
# 959  :  harrys1.:
# 960  :  harrys1&#
# 961  :  harrys1**
# 962  :  harrys1…
# 963  :  harrys1:
# 964  :  harrys1$$
# 965  :  harrys1__
# 966  :  harrys2.
# 967  :  harrys2_
# 968  :  harrys2!
# 969  :  harrys2@
# 970  :  harrys2-
# 971  :  harrys2:
# 972  :  harrys2#
# 973  :  harrys2*
# 974  :  harrys2$
# 975  :  harrys2
# 976  :  harrys2&
# 977  :  harrys2+
# 978  :  harrys2?
# 979  :  harrys2,
# 980  :  harrys2/
# 981  :  harrys2!!
# 982  :  harrys2.:
# 983  :  harrys2&#
# 984  :  harrys2**
# 985  :  harrys2…
# 986  :  harrys2:
# 987  :  harrys2$$
# 988  :  harrys2__
# 989  :  harrys3.
# 990  :  harrys3_
# 991  :  harrys3!
# 992  :  harrys3@
# 993  :  harrys3-
# 994  :  harrys3:
# 995  :  harrys3#
# 996  :  harrys3*
# 997  :  harrys3$
# 998  :  harrys3
# 999  :  harrys3&
# 1000  :  harrys3+
# 1001  :  harrys3?
# 1002  :  harrys3,
# 1003  :  harrys3/
# 1004  :  harrys3!!
# 1005  :  harrys3.:
# 1006  :  harrys3&#
# 1007  :  harrys3**
# 1008  :  harrys3…
# 1009  :  harrys3:
# 1010  :  harrys3$$
# 1011  :  harrys3__
# 1012  :  harrys4.
# 1013  :  harrys4_
# 1014  :  harrys4!
# 1015  :  harrys4@
# 1016  :  harrys4-
# 1017  :  harrys4:
# 1018  :  harrys4#
# 1019  :  harrys4*
# 1020  :  harrys4$
# 1021  :  harrys4
# 1022  :  harrys4&
# 1023  :  harrys4+
# 1024  :  harrys4?
# 1025  :  harrys4,
# 1026  :  harrys4/
# 1027  :  harrys4!!
# 1028  :  harrys4.:
# 1029  :  harrys4&#
# 1030  :  harrys4**
# 1031  :  harrys4…
# 1032  :  harrys4:
# 1033  :  harrys4$$
# 1034  :  harrys4__
# 1035  :  harrys5.
# 1036  :  harrys5_
# 1037  :  harrys5!
# 1038  :  harrys5@
# 1039  :  harrys5-
# 1040  :  harrys5:
# 1041  :  harrys5#
# 1042  :  harrys5*
# 1043  :  harrys5$
# 1044  :  harrys5
# 1045  :  harrys5&
# 1046  :  harrys5+
# 1047  :  harrys5?
# 1048  :  harrys5,
# 1049  :  harrys5/
# 1050  :  harrys5!!
# 1051  :  harrys5.:
# 1052  :  harrys5&#
# 1053  :  harrys5**
# 1054  :  harrys5…
# 1055  :  harrys5:
# 1056  :  harrys5$$
# 1057  :  harrys5__
# 1058  :  harrys6.
# 1059  :  harrys6_
# 1060  :  harrys6!
# 1061  :  harrys6@
# 1062  :  harrys6-
# 1063  :  harrys6:
# 1064  :  harrys6#
# 1065  :  harrys6*
# 1066  :  harrys6$
# 1067  :  harrys6
# 1068  :  harrys6&
# 1069  :  harrys6+
# 1070  :  harrys6?
# 1071  :  harrys6,
# 1072  :  harrys6/
# 1073  :  harrys6!!
# 1074  :  harrys6.:
# 1075  :  harrys6&#
# 1076  :  harrys6**
# 1077  :  harrys6…
# 1078  :  harrys6:
# 1079  :  harrys6$$
# 1080  :  harrys6__
# 1081  :  harrys7.
# 1082  :  harrys7_
# 1083  :  harrys7!
# 1084  :  harrys7@
# 1085  :  harrys7-
# 1086  :  harrys7:
# 1087  :  harrys7#
# 1088  :  harrys7*
# 1089  :  harrys7$
# 1090  :  harrys7
# 1091  :  harrys7&
# 1092  :  harrys7+
# 1093  :  harrys7?
# 1094  :  harrys7,
# 1095  :  harrys7/
# 1096  :  harrys7!!
# 1097  :  harrys7.:
# 1098  :  harrys7&#
# 1099  :  harrys7**
# 1100  :  harrys7…
# 1101  :  harrys7:
# 1102  :  harrys7$$
# 1103  :  harrys7__
# 1104  :  harrys8.
# 1105  :  harrys8_
# 1106  :  harrys8!
# 1107  :  harrys8@
# 1108  :  harrys8-
# 1109  :  harrys8:
# 1110  :  harrys8#
# 1111  :  harrys8*
# 1112  :  harrys8$
# 1113  :  harrys8
# 1114  :  harrys8&
# 1115  :  harrys8+
# 1116  :  harrys8?
# 1117  :  harrys8,
# 1118  :  harrys8/
# 1119  :  harrys8!!
# 1120  :  harrys8.:
# 1121  :  harrys8&#
# 1122  :  harrys8**
# 1123  :  harrys8…
# 1124  :  harrys8:
# 1125  :  harrys8$$
# 1126  :  harrys8__
# 1127  :  harrys9.
# 1128  :  harrys9_
# 1129  :  harrys9!
# 1130  :  harrys9@
# 1131  :  harrys9-
# 1132  :  harrys9:
# 1133  :  harrys9#
# 1134  :  harrys9*
# 1135  :  harrys9$
# 1136  :  harrys9
# 1137  :  harrys9&
# 1138  :  harrys9+
# 1139  :  harrys9?
# 1140  :  harrys9,
# 1141  :  harrys9/
# 1142  :  harrys9!!
# 1143  :  harrys9.:
# 1144  :  harrys9&#
# 1145  :  harrys9**
# 1146  :  harrys9…
# 1147  :  harrys9:
# 1148  :  harrys9$$
# 1149  :  harrys9__
# 1150  :  toulouse0.
# 1151  :  toulouse0_
# 1152  :  toulouse0!
# 1153  :  toulouse0@
# 1154  :  toulouse0-
# 1155  :  toulouse0:
# 1156  :  toulouse0#
# 1157  :  toulouse0*
# 1158  :  toulouse0$
# 1159  :  toulouse0
# 1160  :  toulouse0&
# 1161  :  toulouse0+
# 1162  :  toulouse0?
# 1163  :  toulouse0,
# 1164  :  toulouse0/
# 1165  :  toulouse0!!
# 1166  :  toulouse0.:
# 1167  :  toulouse0&#
# 1168  :  toulouse0**
# 1169  :  toulouse0…
# 1170  :  toulouse0:
# 1171  :  toulouse0$$
# 1172  :  toulouse0__
# 1173  :  toulouse1.
# 1174  :  toulouse1_
# 1175  :  toulouse1!
# 1176  :  toulouse1@
# 1177  :  toulouse1-
# 1178  :  toulouse1:
# 1179  :  toulouse1#
# 1180  :  toulouse1*
# 1181  :  toulouse1$
# 1182  :  toulouse1
# 1183  :  toulouse1&
# 1184  :  toulouse1+
# 1185  :  toulouse1?
# 1186  :  toulouse1,
# 1187  :  toulouse1/
# 1188  :  toulouse1!!
# 1189  :  toulouse1.:
# 1190  :  toulouse1&#
# 1191  :  toulouse1**
# 1192  :  toulouse1…
# 1193  :  toulouse1:
# 1194  :  toulouse1$$
# 1195  :  toulouse1__
# 1196  :  toulouse2.
# 1197  :  toulouse2_
# 1198  :  toulouse2!
# 1199  :  toulouse2@
# 1200  :  toulouse2-
# 1201  :  toulouse2:
# 1202  :  toulouse2#
# 1203  :  toulouse2*
# 1204  :  toulouse2$
# 1205  :  toulouse2
# 1206  :  toulouse2&
# 1207  :  toulouse2+
# 1208  :  toulouse2?
# 1209  :  toulouse2,
# 1210  :  toulouse2/
# 1211  :  toulouse2!!
# 1212  :  toulouse2.:
# 1213  :  toulouse2&#
# 1214  :  toulouse2**
# 1215  :  toulouse2…
# 1216  :  toulouse2:
# 1217  :  toulouse2$$
# 1218  :  toulouse2__
# 1219  :  toulouse3.
# 1220  :  toulouse3_
# 1221  :  toulouse3!
# 1222  :  toulouse3@
# 1223  :  toulouse3-
# 1224  :  toulouse3:
# 1225  :  toulouse3#
# 1226  :  toulouse3*
# 1227  :  toulouse3$
# 1228  :  toulouse3
# 1229  :  toulouse3&
# 1230  :  toulouse3+
# 1231  :  toulouse3?
# 1232  :  toulouse3,
# 1233  :  toulouse3/
# 1234  :  toulouse3!!
# 1235  :  toulouse3.:
# 1236  :  toulouse3&#
# 1237  :  toulouse3**
# 1238  :  toulouse3…
# 1239  :  toulouse3:
# 1240  :  toulouse3$$
# 1241  :  toulouse3__
# 1242  :  toulouse4.
# 1243  :  toulouse4_
# 1244  :  toulouse4!
# 1245  :  toulouse4@
# 1246  :  toulouse4-
# 1247  :  toulouse4:
# 1248  :  toulouse4#
# 1249  :  toulouse4*
# 1250  :  toulouse4$
# 1251  :  toulouse4
# 1252  :  toulouse4&
# 1253  :  toulouse4+
# 1254  :  toulouse4?
# 1255  :  toulouse4,
# 1256  :  toulouse4/
# 1257  :  toulouse4!!
# 1258  :  toulouse4.:
# 1259  :  toulouse4&#
# 1260  :  toulouse4**
# 1261  :  toulouse4…
# 1262  :  toulouse4:
# 1263  :  toulouse4$$
# 1264  :  toulouse4__
# 1265  :  toulouse5.
# 1266  :  toulouse5_
# 1267  :  toulouse5!
# 1268  :  toulouse5@
# 1269  :  toulouse5-
# 1270  :  toulouse5:
# 1271  :  toulouse5#
# 1272  :  toulouse5*
# 1273  :  toulouse5$
# 1274  :  toulouse5
# 1275  :  toulouse5&
# 1276  :  toulouse5+
# 1277  :  toulouse5?
# 1278  :  toulouse5,
# 1279  :  toulouse5/
# 1280  :  toulouse5!!
# 1281  :  toulouse5.:
# 1282  :  toulouse5&#
# 1283  :  toulouse5**
# 1284  :  toulouse5…
# 1285  :  toulouse5:
# 1286  :  toulouse5$$
# 1287  :  toulouse5__
# 1288  :  toulouse6.
# 1289  :  toulouse6_
# 1290  :  toulouse6!
# 1291  :  toulouse6@
# 1292  :  toulouse6-
# 1293  :  toulouse6:
# 1294  :  toulouse6#
# 1295  :  toulouse6*
# 1296  :  toulouse6$
# 1297  :  toulouse6
# 1298  :  toulouse6&
# 1299  :  toulouse6+
# 1300  :  toulouse6?
# 1301  :  toulouse6,
# 1302  :  toulouse6/
# 1303  :  toulouse6!!
# 1304  :  toulouse6.:
# 1305  :  toulouse6&#
# 1306  :  toulouse6**
# 1307  :  toulouse6…
# 1308  :  toulouse6:
# 1309  :  toulouse6$$
# 1310  :  toulouse6__
# 1311  :  toulouse7.
# 1312  :  toulouse7_
# 1313  :  toulouse7!
# 1314  :  toulouse7@
# 1315  :  toulouse7-
# 1316  :  toulouse7:
# 1317  :  toulouse7#
# 1318  :  toulouse7*
# 1319  :  toulouse7$
# 1320  :  toulouse7
# 1321  :  toulouse7&
# 1322  :  toulouse7+
# 1323  :  toulouse7?
# 1324  :  toulouse7,
# 1325  :  toulouse7/
# 1326  :  toulouse7!!
# 1327  :  toulouse7.:
# 1328  :  toulouse7&#
# 1329  :  toulouse7**
# 1330  :  toulouse7…
# 1331  :  toulouse7:
# 1332  :  toulouse7$$
# 1333  :  toulouse7__
# 1334  :  toulouse8.
# 1335  :  toulouse8_
# 1336  :  toulouse8!
# 1337  :  toulouse8@
# 1338  :  toulouse8-
# 1339  :  toulouse8:
# 1340  :  toulouse8#
# 1341  :  toulouse8*
# 1342  :  toulouse8$
# 1343  :  toulouse8
# 1344  :  toulouse8&
# 1345  :  toulouse8+
# 1346  :  toulouse8?
# 1347  :  toulouse8,
# 1348  :  toulouse8/
# 1349  :  toulouse8!!
# 1350  :  toulouse8.:
# 1351  :  toulouse8&#
# 1352  :  toulouse8**
# 1353  :  toulouse8…
# 1354  :  toulouse8:
# 1355  :  toulouse8$$
# 1356  :  toulouse8__
# 1357  :  toulouse9.
# 1358  :  toulouse9_
# 1359  :  toulouse9!
# 1360  :  toulouse9@
# 1361  :  toulouse9-
# 1362  :  toulouse9:
# 1363  :  toulouse9#
# 1364  :  toulouse9*
# 1365  :  toulouse9$
# 1366  :  toulouse9
# 1367  :  toulouse9&
# 1368  :  toulouse9+
# 1369  :  toulouse9?
# 1370  :  toulouse9,
# 1371  :  toulouse9/
# 1372  :  toulouse9!!
# 1373  :  toulouse9.:
# 1374  :  toulouse9&#
# 1375  :  toulouse9**
# 1376  :  toulouse9…
# 1377  :  toulouse9:
# 1378  :  toulouse9$$
# 1379  :  toulouse9__

# %% [markdown]
# # FRONT

# %%
pip install Flask
# Out:
# Requirement already satisfied: Flask in /usr/local/lib/python3.10/dist-packages (2.2.5)
# Requirement already satisfied: Werkzeug>=2.2.2 in /usr/local/lib/python3.10/dist-packages (from Flask) (3.0.1)
# Requirement already satisfied: Jinja2>=3.0 in /usr/local/lib/python3.10/dist-packages (from Flask) (3.1.3)
# Requirement already satisfied: itsdangerous>=2.0 in /usr/local/lib/python3.10/dist-packages (from Flask) (2.1.2)
# Requirement already satisfied: click>=8.0 in /usr/local/lib/python3.10/dist-packages (from Flask) (8.1.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from Jinja2>=3.0->Flask) (2.1.4)

# %%
from flask import Flask, request
import itertools

app = Flask(__name__)

def generate_passwords(strings, digits, specials):
    all_combinations = []

    # Generate combinations of string + special + digits
    combo1 = itertools.product(strings, specials, digits)
    all_combinations.extend(''.join(comb) for comb in combo1)

    # Generate combinations of string + digits + special
    combo2 = itertools.product(strings, digits, specials)
    all_combinations.extend(''.join(comb) for comb in combo2)

    # Filter combinations with length >= 8
    valid_passwords = [password for password in all_combinations if len(password) >= 8]

    return valid_passwords

@app.route('/generate_passwords', methods=['POST'])
def generate_passwords_route():
    string_list = ['abc', 'def']  # Example strings
    digit_list = ['123', '456']   # Example digits
    special_list = ['!@#', '$%^'] # Example specials

    password_combinations = generate_passwords(string_list, digit_list, special_list)

    # Generate output HTML
    output_html = "<h3>Generated Password Combinations:</h3>"
    for i, password in enumerate(password_combinations):
        output_html += f"<p>{i} : {password}</p>"

    return output_html

if __name__ == '__main__':
    app.run(debug=True, port=8000)

# %% [markdown]
# link back to front end

# %%
with open('front.html', 'r') as file:
  html_content = file.read()

# %%
from IPython.display import HTML
HTML(html_content)

# %%
pip install Flask
# Out:
# Requirement already satisfied: Flask in /usr/local/lib/python3.10/dist-packages (2.2.5)
# Requirement already satisfied: Werkzeug>=2.2.2 in /usr/local/lib/python3.10/dist-packages (from Flask) (3.0.1)
# Requirement already satisfied: Jinja2>=3.0 in /usr/local/lib/python3.10/dist-packages (from Flask) (3.1.3)
# Requirement already satisfied: itsdangerous>=2.0 in /usr/local/lib/python3.10/dist-packages (from Flask) (2.1.2)
# Requirement already satisfied: click>=8.0 in /usr/local/lib/python3.10/dist-packages (from Flask) (8.1.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from Jinja2>=3.0->Flask) (2.1.4)

# %%
from flask import Flask, render_template, request
import itertools

app = Flask(__name__)

def generate_passwords(strings, digits, specials):
    all_combinations = []

    # Generate combinations of string + special + digits
    combo1 = itertools.product(strings, specials, digits)
    all_combinations.extend(''.join(comb) for comb in combo1)

    # Generate combinations of string + digits + special
    combo2 = itertools.product(strings, digits, specials)
    all_combinations.extend(''.join(comb) for comb in combo2)

    # Filter combinations with length >= 8
    valid_passwords = [password for password in all_combinations if len(password) >= 8]

    return valid_passwords

@app.route('/')
def index():
    return render_template('index.html')

@app.route('/generate_passwords', methods=['POST'])
def generate_passwords_route():
    string_list = ['abc', 'def']  # Example strings
    digit_list = ['123', '456']   # Example digits
    special_list = ['!@#', '$%^'] # Example specials

    password_combinations = generate_passwords(string_list, digit_list, special_list)

    # Generate output HTML
    output_html = "<h3>Generated Password Combinations:</h3>"
    i = 0
    for password in password_combinations:
        output_html += f"<p>{i} : {password}</p>"
        i += 1

    return output_html

if __name__ == '__main__':
    app.run(debug=True)

# %% [markdown]
# #Computation of Passwords

# %% [markdown]
# #Comparison of Hashes

# %% [markdown]
# **MD5 (Message Digest Algorithm 5):**
# Produces a 128-bit hash value, typically represented as a 32-character hexadecimal number.
# Considered insecure for password storage due to vulnerabilities.
#
# **SHA-1 (Secure Hash Algorithm 1):**
# Produces a 160-bit hash value, typically represented as a 40-character hexadecimal number.
# Deprecated for security-sensitive applications due to vulnerabilities.
#
# **SHA-256, SHA-384, and SHA-512 (Secure Hash Algorithms):**
# Part of the SHA-2 family, producing hash values of 256, 384, and 512 bits, respectively.
# Widely used and considered secure for password hashing.
#
# **bcrypt:**
# Adaptive hash function based on the Blowfish cipher.
# Designed to be slow and computationally intensive to resist brute-force attacks.
# Commonly used for password storage.
#
# **scrypt:**
# Key derivation function designed to be memory-intensive, making it resistant to certain types of hardware attacks.
# Provides protection against both brute-force and rainbow table attacks.
#
# **Argon2:**
# Winner of the Password Hashing Competition (PHC).
# Designed to be memory-hard and resistant to side-channel attacks.
# Provides a high level of security and is recommended for password hashing.

# %% [markdown]
# #Hash model

# %% [markdown]
# **SHA-256**
# SHA, or Secure Hash Algorithm, SHA is a hashing algorithm used in secure connections to prove the integrity and authenticity of a message to the recipient. The SHA algorithm is the default hashing algorithm defined in SSL certificates.

# %%
from hashlib import sha256
h = sha256()
h.update(b'azerty123')
hash = h.hexdigest()
print(hash)

# %%
pip install passlib[bcrypt]
pip install passlib[argon2]

# %% [markdown]
# **Bcrypt :**
#
# Salt is a fixed-length cryptographically-strong random value that is added to the input of hash functions to create unique hashes for every input. A salt is added to make a password hash output unique even for users adopting common passwords.

# %%
import bcrypt

password = b'passWord'

salt = bcrypt.gensalt()
hashed = bcrypt.hashpw(password,salt)

print(hashed)

if bcrypt.checkpw(password, hashed):
    print("match")
else:
    print("does not match")

# %% [markdown]
# **Scrypt :**

# %%
from passlib.hash import scrypt
h = scrypt.hash("password")
print(h)
scrypt.verify("password", h)

# %% [markdown]
# **Argon2** :

# %%
from passlib.hash import argon2
h = argon2.hash("password")
print(h)
argon2.verify("password", h)

# %% [markdown]
# #Conclusion
